# %% [markdown]
# <a href="https://colab.research.google.com/github/VasylDvorakDS/AI-Tutor-of-English-by-Open-AI/blob/master/AI_Tutor_of_English_by_Open_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Устанавливаем и импортируем библиотеки, получаем ключ API OpenAI, подгружаем БД для диалога

# Устанавливаем необходимые библиотеки с помощью pip
# !pip install faiss-cpu langchain==0.0.271 openai==0.28.1 tiktoken  # Установка версий библиотек faiss-cpu, langchain, openai и tiktoken
#!pip install langchain tiktoken  # Установка библиотек langchain и tiktoken (может быть повторно для подтверждения актуальности версий)

# Импортируем необходимые модули и библиотеки
import os  # Модуль для работы с операционной системой, например, для управления файловой системой или переменными окружения
import pandas as pd  # Библиотека pandas для работы с данными в табличном формате, в частности с DataFrame
import getpass  # Модуль для безопасного ввода пароля в терминале
import openai  # Библиотека для взаимодействия с API OpenAI
from langchain.embeddings.openai import OpenAIEmbeddings  # Импорт класса OpenAIEmbeddings для создания эмбеддингов на основе OpenAI
from langchain.vectorstores import FAISS  # Импорт FAISS для работы с векторными базами данных
#from typing import List  # Импорт модуля List из библиотеки typing для аннотации типов, особенно списков
from langchain.text_splitter import RecursiveCharacterTextSplitter  # Импорт класса для рекурсивного разбиения текста на части
import tiktoken # Модуль для работы с токенизацией текста
import re  # Модуль регулярных выражений для обработки строк с использованием шаблонов
import requests  # Модуль для отправки HTTP-запросов, получения данных по URL
#import openai  # Повторный импорт библиотеки openai для взаимодействия с API OpenAI (возможно, для обновления или во избежание ошибок)
import gdown  # Модуль для загрузки файлов из Google Drive по их URL
import time # Импортируем стандартный модуль time, который предоставляет функции для работы с временем
from langchain.docstore.document import Document  # Импорт класса Document для работы с документами в langchain
import textwrap
from IPython.display import clear_output  # Импорт функции для очистки вывода в Jupyter Notebook
#from langchain.chat_models import ChatOpenAI  # Импорт модели ChatOpenAI для создания чат-ботов на основе OpenAI
#from langchain.schema import (AIMessage, HumanMessage, SystemMessage)  # Импорт классов для работы с различными типами сообщений в чатах langchain
#pd.set_option('display.max_colwidth', None)  # Настройка pandas для отображения всех символов в ячейках DataFrame, без сокращения длинных строк

# Функция getpass.getpass() запрашивает ввод пароля или ключа без отображения ввода на экране
openai_key = getpass.getpass("OpenAI API Key:")
# Установка ключа API в переменную окружения
os.environ["OPENAI_API_KEY"] = openai_key
# Установка ключа API для использования библиотекой openai
openai.api_key = openai_key

import faiss
import pickle
import gdown
from langchain.vectorstores import FAISS
from langchain.docstore.in_memory import InMemoryDocstore

def load_faiss_index_from_drive(embeddings):
    # Скачиваем файлы из Google Drive
    gdown.download('https://drive.google.com/uc?id=1jxGqxcb0N31Cxk5aYSXgrVw6FGGoCiES', '/content/faiss_index.faiss', quiet=False)
    gdown.download('https://drive.google.com/uc?id=1SEjtg2P7ovMOIRTPrBshZUQeTUfDs3n7', '/content/faiss_metadata.pkl', quiet=False)

    # Загружаем индекс FAISS
    index = faiss.read_index('/content/faiss_index.faiss')

    # Загружаем метаданные
    with open('/content/faiss_metadata.pkl', 'rb') as f:
        metadata = pickle.load(f)

    # Восстанавливаем объект InMemoryDocstore из метаданных
    docstore = InMemoryDocstore(metadata['docstore'])

    # Восстанавливаем объект FAISS из индекса и метаданных
    db = FAISS(embedding_function=embeddings.embed_query, index=index, docstore=docstore, index_to_docstore_id=metadata['index_to_docstore_id'])

    return db

# Пример использования
embeddings = OpenAIEmbeddings()
db = load_faiss_index_from_drive(embeddings)

clear_output()  # Очистка вывода в ячейке Jupyter Notebook для улучшения читаемости и удобства работы

# %% [markdown]
# ## Загрузка базы знаний

# %% [markdown]
# Ссылка на базу знаний:
#
# https://docs.google.com/document/d/1aNcrmTAok2PCV5r6xPGswY8s7NKNlgC-mxyosEipjfo/edit?usp=sharing

# %%
# Функция загрузки данных, которая принимает строку url в качестве аргумента и возвращает строку (текст документа)

def load_document_text_google(url: str) -> str:

    # Выполнение HTTP GET запроса для получения содержимого документа
    response = requests.get(url.replace('/edit?usp=sharing', '/export?format=txt'))

    # Проверка успешности запроса. Если запрос завершился с ошибкой (статусный код 4xx или 5xx), вызовется исключение, которое прервет выполнение функции
    response.raise_for_status()

    # Возвращение текста документа в качестве результата функции
    return response.text

# %%
# Загружаем наш документ
text = load_document_text_google('https://docs.google.com/document/d/1aNcrmTAok2PCV5r6xPGswY8s7NKNlgC-mxyosEipjfo/edit?usp=sharing')

# %% [markdown]
# Содержание документа

# %%
text
# Out:
# "\ufeff# Курсы английского языка онлайн под ваши цели\r\nПредоставим программу обучения, исходя из ваших запросов, поможем достичь цели, используя уроки по самым актуальным темам. \r\n\r\n\r\n## Что нужно, чтобы начать обучение?\r\n\r\n\r\nАбсолютно ничего, кроме устройства, у которого есть микрофон, камера и доступ к сайту Skyeng.\r\n\r\n\r\n## Не получается прийти на урок, что делать?\r\n\r\n\r\nНичего страшного, бывает! У учеников есть возможность отменить занятие за 8 часов до назначенного времени без потери оплаты. Так вы сможете переназначить его на удобное время, а у преподавателя останется возможность скорректировать расписание.\r\n\r\n\r\n## Как стать Преподавателем?\r\n\r\n\r\nОставьте заявку на сайте и запишите короткое аудиоинтервью о своем опыте. Мы свяжемся с вами по почте и расскажем о предстоящих этапах. Не переживайте: сначала мы познакомим вас с нашей платформой, затем методист сыграет роль ученика на вашем первом занятии. После успешного прохождения отбора вы сможете открыть расписание и сразу начать преподавать.\r\n\r\n\r\n## Мало свободного времени, боюсь, не буду успевать заниматься\r\n\r\n\r\nПрограммы обучения максимально гибкие — можно заниматься где и когда угодно, в удобном для вас темпе. Мы подберем учителя и график, а также в любое время сможем изменить расписание, сделать перерыв или помочь скорректировать программу.\r\n\r\n\r\n## Нужно ли что-то из канцелярии для прохождения пробного урока?\r\n\r\n\r\nНет, для обучения в нашей школе достаточно компьютера.\r\n\r\n\r\n## Сколько длится одно занятие по английскому языку?\r\n\r\n\r\nДлительность ознакомительной встречи — 30 минут, все остальные занятия на языковых курсах (после оплаты) длятся 50 минут. \r\n\r\n\r\n## Начать заниматься английским проще, чем кажется!\r\n\r\n\r\n1. Оставьте заявку  \r\nМы поможем познакомиться со школой и сразу начать заниматься на курсе\r\n\r\n\r\n2. Начните заниматься  \r\nПриступите к занятиям с лучшими преподавателями. Нарабатывайте новые навыки для желаемой профессии\r\n\r\n\r\n3. Получите доступ к разговорным клубам  \r\nНачните оттачивать полученные навыки параллельно с занятиями на курсе\r\n\r\n\r\nОставить заявку\r\n\r\n\r\nОставляя заявку, вы принимаете условия «Политики конфиденциальности»\r\n\r\n\r\n## Занимайтесь английским в одной из крупнейших онлайн-школ в Европе\r\n\r\n\r\n15 000+ преподавателей  \r\nВ Skyeng английский преподают опытные педагоги со всего мира. Мы помогаем им расти и делать занятия еще лучше: повышать квалификацию каждый год и учиться у зарубежных коллег.\r\n\r\n\r\n150 000+ учеников  \r\nПредприниматели, студенты, специалисты, путешественники и просто ценители общения — такие разные, но все одинаково любимые.\r\n\r\n\r\n25 000 000 индивидуальных уроков  \r\nМы следим за вашими результатами, помогаем преодолеть языковой барьер, находим пути к цели и даем обратную связь.\r\n\r\n\r\n## Начните общаться на английском уже сегодня\r\n\r\n\r\n### Преодолеть языковой барьер\r\n\r\n\r\nВыберите преподавателя →  \r\nЗанимайтесь с тем, кто больше нравится. Если вам не подойдёт преподаватель, его можно сменить в любой момент.\r\n\r\n\r\nПопробуйте Talks →  \r\nУчитесь говорить и понимать по-английски: общайтесь с преподавателями — носителями языка из разных стран по 15 минут в день.\r\n\r\n\r\n### Мобильное приложение\r\n\r\n\r\nЗанимайтесь по нашим материалам в любое время. Учите новую лексику на тренажере слов, практикуйте аудирование и выполняйте задания.\r\n\r\n\r\n## Подбираем преподавателя под ваши цели и интересы\r\n\r\n\r\nВам точно будет о чем поговорить. У всех преподавателей есть педагогическое образование. Только 5 кандидатов из 100 проходят отбор в Skyeng.\r\n\r\n\r\n# Процесс обучения в Skyeng\r\n\r\n\r\n  Выбирайте преподавателя, который подойдёт именно вам\r\n\r\n\r\n  Занимайтесь в любое удобное время, с любого девайса\r\n\r\n\r\n  Обучайтесь по индивидуальной программе, разработанной профессиональными методистами\r\n\r\n\r\n  Достигайте целей эффективно на современной платформе \ ...

# %% [markdown]
# ## Деление на чанки

# %% [markdown]
# "Чанки" (от английского "chunks") - это термин, который в программировании и обработке данных обычно обозначает небольшие блоки данных. Так что основная цель использования чанков - это обработка больших объемов данных более эффективно и управляемо.

# %% [markdown]
# `RecursiveCharacterTextSplitter `- это класс в библиотеке langchain, который предназначен для разделения текста на фрагменты или "чанки".
#
#
# > По умолчанию список разделителей включает в себя следующие символы: `['\n\n', '\n', ' ', '']`. Это означает, что сначала текст пытается разбиться по двум символам новой строки, затем по одному символу новой строки, затем по пробелу, и в конце, если ни один из предыдущих разделителей не сработал, текст разбивается на отдельные символы.

# %%
# Функция разделения текста на чанки, которая принимает текст в виде строки, размер чанка и количество перекрывающихся символов между чанками

def split_text_into_chunks(text: str, chunk_size: int, chunk_overlap: int) -> str:

    # Инициализация пустого списка для хранения частей текста (чанков)
    source_chunks = []

    # Создание объекта класса RecursiveCharacterTextSplitter с заданным размером чанка и перекрытием для разбиения текста на части
    splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)

    # Цикл для итерации по каждому чанкованному фрагменту текста
    for chunk in splitter.split_text(text):

        # Создание объекта Document для каждого чанка текста и добавление его в список source_chunks
        # page_content хранит текст чанка, а metadata (пока пустой словарь) может содержать дополнительную информацию
        source_chunks.append(Document(page_content=chunk, metadata={}))

    # Возвращение списка объектов Document, каждый из которых содержит часть исходного текста
    return source_chunks

# %% [markdown]
# Вызов функции

# %%
# Задаем размер чанка
chunk_size = 1024

# Задаем размер перекрытия чанков
chunk_overlap = 0

# Вызываем функцию разеделения текста на чанки
source_chunks = split_text_into_chunks(text, chunk_size, chunk_overlap)

print("Общее количество чанков: ", len(source_chunks))
print("Пример чанка № 12:\n", source_chunks[11])
# Out:
# Общее количество чанков:  125
# Пример чанка № 12:
#  page_content='1. Дополнительные уроки в подарок\r\n2. 1 месяц разговорного клуба\r\n\r\n\r\n## Стоимость курсов с русскоязычным преподавателем\r\n\r\n\r\nВыучите новые слова на все случаи жизни, разберетесь даже в сложных временах и сломаете языковой барьер.\r\nот 950 ₽ за урок\r\n\r\n\r\n## Английский с англоязычным преподавателем\r\n\r\n\r\nНаучитесь понимать живую речь носителей и узнаете выражения, которые они используют каждый день.\r\nот 3 247 ₽ за урок\r\n\r\n\r\n## Премиум английский\r\n\r\n\r\nПремиум-преподаватели, гибкий график, персональный менеджер, индивидуальный план обучения. А также разговорный премиум-клуб и скрининг-тесты.\r\nот 1 290 ₽ за урок\r\n\r\n\r\n# Английский язык для взрослых онлайн\r\n\r\n\r\nПроходите индивидуальные уроки в удобное время из любой точки земного шара, от Москвы до Бангкока, и используйте английский уверенно в любой ситуации\r\n\r\n\r\n\r\n\r\n## Как проходит индивидуальное обучение в Skyeng\r\n\r\n\r\n1. Созваниваетесь с репетитором на нашей платформе\r\n2. Общаетесь на английском и выполняете упражнения' metadata={}

# %% [markdown]
# ## Эмбеддинги

# %% [markdown]
# >Эмбеддинги (или векторные представления) - это способ представления текстовых данных в виде числовых векторов, которые могут быть обработаны машинными алгоритмами

# %% [markdown]
# Создание эмбеддингов для чанок c помощью OpenAI

# %%
embeddings = OpenAIEmbeddings()  # Создаем объект эмбеддингов от OpenAI

# %%
embeddings
# Out:
# OpenAIEmbeddings(client=<class 'openai.api_resources.embedding.Embedding'>, model='text-embedding-ada-002', deployment='text-embedding-ada-002', openai_api_version='', openai_api_base='', openai_api_type='', openai_proxy='', embedding_ctx_length=8191, openai_api_key='dfghrilt4567erhgdfku5', openai_organization='', allowed_special=set(), disallowed_special='all', chunk_size=1000, max_retries=6, request_timeout=None, headers=None, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={})

# %% [markdown]
# ## FAISS

# %% [markdown]
# >FAISS — это способ структурированного хранения эмбеддингов (векторов) и выполнения быстрого поиска по ним. FAISS позволяет легко и быстро находить семантически близкие векторы в большой базе данных векторов

# %% [markdown]
# Вспомогательная функция подсчета токенов

# %%
# Функция для подсчета токенов при создании базы эмбеддингов,которая принимает текст и название кодировки, используемой для токенизации текста
def num_tokens_from_string(string: str, encoding_name: str) -> int:

    # Получаем объект кодировки по ее имени
    encoding = tiktoken.get_encoding(encoding_name)

    # Кодируем строку в токены и подсчитываем количество токенов
    num_tokens = len(encoding.encode(string))

    # Возвращаем количество токенов
    return num_tokens

# %% [markdown]
# Функция создание базы данных эмбедингов FAISS с помощью библиотеки langchain

# %%
# Функция перевода чанков текста в векторы многомерного пространства
def create_faiss_index_from_chunks(source_chunks, embeddings):

    # Инициализируем счетчик токенов
    count_tokens = 0

    # Если документ не пуст, создаем и сохраняем базу индексов эмбеддингов фрагментов документа
    if len(source_chunks):

        # Начало отсчета времени
        start_time = time.time()

        # Создаем базу данных эмбеддингов
        db = FAISS.from_documents(source_chunks, embeddings)

        # Конец отсчета времени
        end_time = time.time()

        # Подсчет затраченного времени
        elapsed_time2 = end_time - start_time

        print(f"Время создания векторной базы: {elapsed_time2:.2f} секунд")

        # Подсчитываем количество токенов в документе
        count_token = num_tokens_from_string(' '.join([x.page_content for x in source_chunks]), "cl100k_base")
        print('Количество токенов в документе :', count_token)
        print('ЦЕНА запроса:', 0.0001 * (count_token / 1000), ' $')  # Вычисляем стоимость запроса

    return db

# %% [markdown]
# Вызов функции

# %%
# Вызываем функцию перевода текста в векторы
db = create_faiss_index_from_chunks(source_chunks, embeddings)
# Out:
# Время создания векторной базы: 1.45 секунд
# Количество токенов в документе : 52299
# ЦЕНА запроса: 0.0052299  $

# %% [markdown]
# Результат работы:
# > База данных FAISS

# %%
db

# %%
# Вывод информации об индексе FAISS
def print_faiss_index_info(db):
    index = db.index  # Получаем индекс FAISS
    print(f"Количество векторов в индексе: {index.ntotal}")
    print(f"Размерность векторов: {index.d}")

print_faiss_index_info(db)
# Out:
# Количество векторов в индексе: 125
# Размерность векторов: 1536

# %%
db.docstore._dict # словарь объекта хранилища документов
# Out:
# {'5c6627b4-22cf-48b1-8b19-6b4642fe83e4': Document(page_content='\ufeff# Курсы английского языка онлайн под ваши цели\r\nПредоставим программу обучения, исходя из ваших запросов, поможем достичь цели, используя уроки по самым актуальным темам. \r\n\r\n\r\n## Что нужно, чтобы начать обучение?\r\n\r\n\r\nАбсолютно ничего, кроме устройства, у которого есть микрофон, камера и доступ к сайту Skyeng.\r\n\r\n\r\n## Не получается прийти на урок, что делать?\r\n\r\n\r\nНичего страшного, бывает! У учеников есть возможность отменить занятие за 8 часов до назначенного времени без потери оплаты. Так вы сможете переназначить его на удобное время, а у преподавателя останется возможность скорректировать расписание.\r\n\r\n\r\n## Как стать Преподавателем?\r\n\r\n\r\nОставьте заявку на сайте и запишите короткое аудиоинтервью о своем опыте. Мы свяжемся с вами по почте и расскажем о предстоящих этапах. Не переживайте: сначала мы познакомим вас с нашей платформой, затем методист сыграет роль ученика на вашем первом занятии. После успешного прохождения отбора вы сможете открыть расписание и сразу начать преподавать.', metadata={}),
#  '346c357c-27a9-4d12-a10c-b0f5ad975c55': Document(page_content='## Мало свободного времени, боюсь, не буду успевать заниматься\r\n\r\n\r\nПрограммы обучения максимально гибкие — можно заниматься где и когда угодно, в удобном для вас темпе. Мы подберем учителя и график, а также в любое время сможем изменить расписание, сделать перерыв или помочь скорректировать программу.\r\n\r\n\r\n## Нужно ли что-то из канцелярии для прохождения пробного урока?\r\n\r\n\r\nНет, для обучения в нашей школе достаточно компьютера.\r\n\r\n\r\n## Сколько длится одно занятие по английскому языку?\r\n\r\n\r\nДлительность ознакомительной встречи — 30 минут, все остальные занятия на языковых курсах (после оплаты) длятся 50 минут. \r\n\r\n\r\n## Начать заниматься английским проще, чем кажется!\r\n\r\n\r\n1. Оставьте заявку  \r\nМы поможем познакомиться со школой и сразу начать заниматься на курсе\r\n\r\n\r\n2. Начните заниматься  \r\nПриступите к занятиям с лучшими преподавателями. Нарабатывайте новые навыки для желаемой профессии\r\n\r\n\r\n3. Получите доступ к разговорным клубам  \r\nНачните оттачивать полученные навыки параллельно с занятиями на курсе', metadata={}),
#  '33f92389-e3c2-43f8-bc23-c7c72aabb135': Document(page_content='Оставить заявку\r\n\r\n\r\nОставляя заявку, вы принимаете условия «Политики конфиденциальности»\r\n\r\n\r\n## Занимайтесь английским в одной из крупнейших онлайн-школ в Европе\r\n\r\n\r\n15 000+ преподавателей  \r\nВ Skyeng английский преподают опытные педагоги со всего мира. Мы помогаем им расти и делать занятия еще лучше: повышать квалификацию каждый год и учиться у зарубежных коллег.\r\n\r\n\r\n150 000+ учеников  \r\nПредприниматели, студенты, специалисты, путешественники и просто ценители общения — такие разные, но все одинаково любимые.\r\n\r\n\r\n25 000 000 индивидуальных уроков  \r\nМы следим за вашими результатами, помогаем преодолеть языковой барьер, находим пути к цели и даем обратную связь.\r\n\r\n\r\n## Начните общаться на английском уже сегодня\r\n\r\n\r\n### Преодолеть языковой барьер\r\n\r\n\r\nВыберите преподавателя →  \r\nЗанимайтесь с тем, кто больше нравится. Если вам не подойдёт преподаватель, его можно сменить в любой момент.\r\n\r\n\r\nПопробуйте Talks →', metadata={}),
#  '5b9b320d-eaf2-4e52-8897-f338c3f1bf40': Document(page_content='Учитесь говорить и понимать по-английски: общайтесь с преподавателями — носителями языка из разных стран по 15 минут в день.\r\n\r\n\r\n### Мобильное приложение\r\n\r\n\r\nЗанимайтесь по нашим материалам в любое время. Учите новую лексику на тренажере слов, практикуйте аудирование и выполняйте задания.\r\n\r\n\r\n## Подбираем преподавателя под ваши цели и интересы\r\n\r\n\r\nВам точно будет о чем поговорить. У всех преподавателей есть педагогическое образование. Только 5 кандидатов из 100 проходят отбор в Skyeng.\r\n\r\n\r\n# Процесс обучения в Skyeng\r\n\r\n\r\n  Выбирайте преподавателя, который подойдёт именно вам\r\n\r\n\r\n  Занимайтесь в любое удобное время, с любого девайса\r\n\r\n\r\n  Обучайтесь по индивидуальной программе, разработанной профессиональными методистами\r\n\r\n\r\n  Достигайте целей эффективно на современной платформе \r\n\r\n\r\n# Платформа\r\n\r\n\r\nОнлайн-платформа — это интерактивный онлайн-учебник, где вы созваниваетесь с преподавателем, выполняете задания, делаете домашку и пользуетесь всеми образовательными ресурсами школы.', metadata={}),
#  'd2b4ecb0-c6f7-40cd-ab2b-13024dc78d6b': Document(page_content='## Как проходят занятия на платформе\r\n\r\n\r\n1. Не нужно ничего скачивать и устанавливать — вы попадаете на урок из личного кабинета прямо в браузере.\r\n2. Во время урока вы одновременно общаетесь с преподавателем по видео и выполняете интерактивные задания.\r\n3. Правильные и неправильные ответы отображаются сразу, а на полях можно делать заметки, чтобы не забыть новое слово или правило.\r\n4. Упражнения и видеосвязь с учителем будут доступны одновременно на одной странице.\r\n\r\n\r\n## Обучайтесь эффективнее с приложением\r\n\r\n\r\nВ приложении вы можете не только подключаться к урокам с преподавателем и выполнять домашку, но и практиковаться самостоятельно с большим количеством упражнений и тренажёром слов — умные алгоритмы помогут выучить лексику в 3 раза быстрее среднего.\r\n\r\n\r\n## Все возможности платформы\r\n\r\n\r\n1. Доступ к обучению\r\n2. Тренажёр слов\r\n3. Домашние задания', metadata={}),
#  'fc78d80a-c118-4da7-86e1-cf2dd9ecc2f5': Document(page_content='Преподаватель может подобрать упражнения, соответствующие вашему уровню и потребностям, и дать их в качестве домашнего задания. Открыть задания на платформе и приступить к выполнению в удобном для вас темпе можно когда угодно.\r\n\r\n\r\n### Автоматическая проверка\r\n\r\n\r\nВам не придётся ждать, пока учитель проверит задания — правильные и неправильные ответы отображаются сразу.\r\n\r\n\r\n### Справедливая оценка\r\n\r\n\r\nЗа каждый ответ в домашнем задании вы получаете определённое количество баллов, от которых зависит финальная оценка.\r\n\r\n\r\n### Синхронизация с преподавателем\r\n\r\n\r\nПреподаватель видит, как вы выполняете упражнения, чтобы подбодрить или подсказать в нужный момент.\r\n\r\n\r\n### Персональный подход\r\n\r\n\r\nВесь материал тщательно подбирается и проверяется преподавателем, чтобы соответствовать вашим интересам, целям, запросам.\r\n\r\n\r\n### Разнообразные задания\r\n\r\n\r\nУпражнения по видео, чтение статей, написание эссе, прослушивание аудио, перевод, практика речи и многое другое.\r\n\r\n\r\n### Отслеживание прогресса', metadata={}),
#  'b6a29b9b-6dd9-4b05-b09d-0c2e757117cd': Document(page_content='Статистика по работе на уроках и в домашних заданиях составляется автоматически, чтобы и преподаватель, и вы всегда могли оценить свою успеваемость и обратить внимание на слабые места.\r\n\r\n\r\n### Доступ к материалам уроков\r\n\r\n\r\nВы всегда можете вернуться к любому из пройденных уроков, чтобы повторить пройденное или вспомнить забытое.\r\n\r\n\r\n## Личный кабинет\r\n\r\n\r\nНа главной странице личного кабинета вы найдёте дату следующего занятия, актуальную домашку, статистику прогресса и прогноз достижения цели. Отсюда можно попасть в кошелёк, настройки профиля и платформы, а также чат с поддержкой. Все подарки и акции отображаются в личном кабинете в первую очередь.\r\n\r\n\r\n## Запишитесь на бесплатную ознакомительную встречу\r\n\r\n\r\nМы покажем, как работает платформа, а ещё определим ваш уровень английского, расскажем об особенностях обучения онлайн и поможем подобрать учителя.\r\n# Наш подход к обучению', metadata={}),
#  '706abc9f-3dfe-47a2-b3e1-b0c555b1ba9f': Document(page_content='У каждого свой языковой уровень, темп и удобный ему формат обучения. Мы подбираем план обучения под потребности и цели каждого ученика и, самое главное, доводим до результата с помощью проверенной коммуникативной методологии и системы контроля прогресса. Нам важно, чтобы вы начали использовать язык уже с первого занятия!\r\n\r\n\r\n## Как мы достигаем эффективного обучения?\r\n\r\n\r\n1. Наши курсы разработаны лучшими методистами школы с длительным опытом преподавания онлайн и завалидированы иностранными экспертами.\r\n2. Эмоциональный интеллект, теория лени, гастротуризм, цифровой след, рейтинг городов — никаких школьных топиков. Наши уроки построены на темах, о которых говорит весь мир, с упором на использование в реальной жизни.\r\n3. Мы строим учебный план, основываясь на ваших интересах и целях. Мы подбираем самые подходящие методы обучения в зависимости от ваших предпочтений и навыков.', metadata={}),
#  '72ea8b48-739f-46f2-a735-2d6bb2bdfecc': Document(page_content='4. Интерактивные упражнения на грамматику, лексику, говорение, чтение, письмо. Лёгкий интерфейс, удобный словарь, встроенный в платформу. Всё для эффективного изучения языка в одной экосистеме.\r\n5. Вы можете сочетать разные форматы обучения: от индивидуальных занятий с преподавателем и групповых разговорных клубов до самостоятельных тренировок в приложении.\r\n6. В личном кабинете вы найдёте виджет прогресса изучения языка, который покажет, как растёт ваш уровень и какие навыки требуют доработки. Кроме того, виджет даёт рекомендации для самостоятельной тренировки различных аспектов языка.\r\n7. Авторские курсы Skyeng разработаны в соответствии со стандартами владения иностранным языком, принятыми в мире: Common European Framework of Reference (CEFR) и Global Scale of English (GSE).\r\n8. Мы готовим к сдаче IELTS на основе официальных материалов издательства Кембриджского университета, адаптированных под интерактивную платформу школы.', metadata={}),
#  '7763bf0d-e4e4-4b60-86e8-7bc27f9bb54f': Document(page_content='9. Над нашими курсами работает огромная команда: методисты, контент-продюсеры, нейтив-райтеры, саунд-дизайнеры, верстальщики, дизайнеры, редакторы, спикеры с самыми разными акцентами. Курсы тестируются и тщательно прорабатываются перед тем, как появиться на платформе.\r\n10. Мы придерживаемся стандарта CEFR — эта система оценивает и растит ваши знания языка согласно 6 уровням.\r\n11. Создавая контент, мы ориентируемся именно на систему CEFR, а ученики повышают уровень английского по стандартным уровням этой системы:\r\n    - A1 — Beginner + Elementary\r\n    - A2 — Pre-Intermediate\r\n    - B1 — Intermediate\r\n    - B2 — Upper-Intermediate\r\n    - C1 — Advanced\r\n    - C2 — Proficiency\r\n\r\n\r\n## Почему это удобно?\r\n\r\n\r\nСледуя системе CEFR, вы можете обозначать свой уровень языка в резюме и понимать, до какого уровня вам необходимо подтянуть знания.\r\n\r\n\r\n\r\n\r\n## Как проходит вводный урок с методистом\r\n\r\n\r\n1. Определим уровень\r\n2. Покажем платформу\r\n3. Расскажем, как проходят занятия\r\n4. Подберём курс', metadata={}),
#  'b65bb8ad-aa55-443f-85dd-f6f56ecc6e48': Document(page_content='# Стоимость курсов английского языка в Skyeng\r\n\r\n\r\nЗанимайтесь один на один, не выходя из дома, в нашей школе английского языка по цене ниже репетитора. Стоимость обучения на курсах английского языка включает подбор преподавателя по личной совместимости и онлайн доступ в виртуальный класс с учебными материалами.\r\n\r\n\r\n## При оплате занятий сразу вы получите бонусы\r\n\r\n\r\n1. Дополнительные уроки в подарок\r\n2. 1 месяц разговорного клуба\r\n\r\n\r\n## Стоимость курсов с русскоязычным преподавателем\r\n\r\n\r\nВыучите новые слова на все случаи жизни, разберетесь даже в сложных временах и сломаете языковой барьер.\r\nот 950 ₽ за урок\r\n\r\n\r\n## Английский с англоязычным преподавателем\r\n\r\n\r\nНаучитесь понимать живую речь носителей и узнаете выражения, которые они используют каждый день.\r\nот 3 247 ₽ за урок\r\n\r\n\r\n## Премиум английский\r\n\r\n\r\nПремиум-преподаватели, гибкий график, персональный менеджер, индивидуальный план обучения. А также разговорный премиум-клуб и скрининг-тесты.\r\nот 1 290 ₽ за урок', metadata={}),
#  '6958ee21-b722-42cb-a104-0a824138feb4': Document(page_content='# Английский язык для взрослых онлайн\r\n\r\n\r\nПроходите индивидуальные уроки в удобное время из любой точки земного шара, от Москвы до Бангкока, и используйте английский уверенно в любой ситуации\r\n\r\n\r\n\r\n\r\n## Как проходит индивидуальное обучение в Skyeng\r\n\r\n\r\n1. Созваниваетесь с репетитором на нашей платформе\r\n2. Общаетесь на английском и выполняете упражнения\r\n3. Делаете домашку и следите за своим прогрессом\r\n\r\n\r\n## Разговорная практика с первого урока\r\n\r\n\r\nОбщайтесь на английском, слушайте спикеров из разных стран и учитесь понимать любой акцент\r\n\r\n\r\n## Учёба всегда под рукой\r\n\r\n\r\nТренируйте навыки, учите слова, делайте домашки, смотрите видео и слушайте аудио на телефоне или компьютере\r\n\r\n\r\n## Поддержка 24/7\r\n\r\n\r\nОтдел заботы без выходных готов решить все ваши вопросы\r\n\r\n\r\n\r\n\r\n## Почему курсы английского языка для взрослых в Skyeng — это эффективно\r\n\r\n\r\n### Индивидуальная программа\r\n\r\n\r\nПоможем выбрать цель обучения и подберём упражнения, которые помогут достичь её быстро и с удовольствием', metadata={}),
#  'd51b29fd-5874-45df-a68d-72366d01bb41': Document(page_content='### Мировые стандарты\r\n\r\n\r\nПрограммы соответствуют международным стандартам CEFR и GSE\r\n\r\n\r\n### Наглядный прогресс\r\n\r\n\r\nПокажем динамику прогресса по каждому навыку — чтение, аудирование, лексика, грамматика и письмо\r\n\r\n\r\n### Тарифы под ваши запросы. Выберите подходящий\r\n\r\n\r\nЧем больше занятий в пакете, тем дешевле каждый урок\r\n\r\n\r\n#### Стандарт\r\n\r\n\r\nот 950 ₽ за урок\r\n\r\n\r\n- Занятия по 50 минут с преподавателем\r\n- Русскоязычные преподаватели английского языка с опытом от 1 года\r\n- Доступ к интерактивной платформе и всем тренажёрам школы\r\n- Возможность переносить по 2 урока в месяц бесплатно\r\n- Поддержка в чате и по телефону\r\n\r\n\r\n\r\n\r\n#### ПОПУЛЯРНЫЙ\r\n\r\n\r\nПремиум от 1 290 ₽ за урок\r\n\r\n\r\n- Персональный подход и премиум-преподаватели\r\n- Русскоязычные преподаватели английского языка с опытом от 5 лет\r\n- Доступ к платформе и тренажёрам школы\r\n- Возможность переносить уроки от занятия к занятию\r\n- Персональный менеджер 24/7\r\n\r\n\r\n\r\n\r\n#### Нейтив\r\n\r\n\r\nот 3 247 ₽ за урок\r\n\r\n\r\n- Занятия по 50 минут с носителем языка', metadata={}),
#  '90a1a34b-1a56-41a1-b3ab-5b943c86b54b': Document(page_content='- Преподаватели — носители языка английского языка с опытом от 1 года\r\n- Доступ к интерактивной платформе и всем тренажёрам школы\r\n- Подготовка к экзамену IELTS\r\n- Возможность переносить по 2 урока в месяц бесплатно\r\n- Поддержка в чате и по телефону\r\n\r\n\r\n\r\n\r\n## Сильные преподаватели с разными интересами. Найдите своего\r\n\r\n\r\nЗанимайтесь с тем, кто больше нравится. Если вам не подойдёт преподаватель курса, его можно сменить в любой момент\r\n\r\n\r\n## Разговорная практика с носителями английского языка в Talks\r\n\r\n\r\nTalks — 15-минутные разговоры 1 на 1 с преподавателями со всего мира.\r\n\r\n\r\n## Персональный подход на тарифе Премиум\r\n\r\n\r\nИ ещё 150 преподавателей с опытом от 5 лет, прошедших дополнительное обучение\r\n\r\n\r\nПреподаватели на связи вне занятий\r\n\r\n\r\nПрошли дополнительное обучение, могут построить программу с использованием ваших материалов\r\n\r\n\r\n### Персональное сопровождение\r\n\r\n\r\nПоможет обучаться максимально эффективно. Возможность перестраивать расписание хоть каждый день', metadata={}),
#  'befae01f-9021-4397-9557-8fcb32fcea8c': Document(page_content='### Погружение в языковую среду\r\n\r\n\r\nБесплатные безлимитные встречи разговорного клуба и скрининг-тесты. Индивидуальный план, доступ к IT-курсу\r\n\r\n\r\n## Бесплатный пробный урок\r\n\r\n\r\nНачните заниматься английским уже на этой неделе\r\n\r\n\r\n1. Оставьте заявку\r\n\r\n\r\nПосле отправки заявки вы сможете оплатить пакет сразу и получить бонусы или пройти бесплатный вводный урок.\r\n\r\n\r\n2. Пройдите вводный урок\r\n\r\n\r\nПознакомимся, определим ваш уровень, покажем как проходят занятия, так же вы можете оплатить интересующий ваш пакет сразу.\r\n\r\n\r\n3. Выберите преподавателя\r\n\r\n\r\nПосле оплаты мы поможем подобрать преподавателя, который соответствует вашим целям и потребностям.\r\n\r\n\r\n## Курсы английского под ваши цели. Выберите подходящий\r\n\r\n\r\nПрограмму любого курса можно скорректировать в зависимости от ваших потребностей и целей\r\n\r\n\r\n## Выберите цель и уровень\r\n\r\n\r\n### По темам\r\n\r\n\r\n- Подготовка к экзамену IELTS\r\n  - С нами вы получите нужный балл, 80% учеников уже сдали экзамен на желаемую оценку\r\n- Курс английского для путешествий', metadata={}),
#  'ffad3bc3-9b21-4d83-9042-15828d4d8807': Document(page_content='- 128 урока • от 890 ₽ за урок\r\n  - Английский язык для поездок за границу и общения с иностранцами\r\n- Курс разговорного английского языка\r\n  - 128 урока • от 890 ₽ за урок\r\n\r\n\r\n### По уровням\r\n\r\n\r\n- Курс английского с нуля\r\n  - 128 урока • от 890 ₽ за урок\r\n  - Основы языка для тех, кто только встал на путь изучения английского\r\n- Курс английского для начинающих\r\n  - 128 уроков • от 890 ₽ за урок\r\n  - Программа рассчитана на тех, кто уже владеет базовыми знаниями английского языка\r\n- Для продолжающих\r\n  - 128 уроков • от 890 ₽ за урок\r\n  - Освоите уровень Pre-Intermediate и сможете использовать английский язык в общении\r\n\r\n\r\n\r\n\r\n\r\n\r\n## Что нужно, чтобы начать учить английский онлайн?\r\n\r\n\r\nДля обучения нужны только компьютер или телефон с микрофоном, камерой и доступом в интернет. Где бы вы ни находились — в Москве, Казани, Новосибирске или на Бали — онлайн-школа английского будет под рукой. \r\n\r\n\r\n## Когда можно пройти ознакомительный урок?', metadata={}),
#  '4fc52aac-03b3-4955-a37c-70b36221ee20': Document(page_content='Вы можете познакомиться со школой в любой удобный для вас момент. Для этого просто оставьте заявку и запишитесь на урок.\r\n\r\n\r\n## Не получается прийти на урок, что делать?\r\n\r\n\r\nНичего страшного, бывает! У учеников есть возможность отменить занятие за 8 часов до назначенного времени без потери оплаты. Так вы сможете переназначить его на удобное время, а у преподавателя останется возможность скорректировать расписание.\r\n\r\n\r\n## У меня мало свободного времени, я буду успевать заниматься?\r\n\r\n\r\nИзучение английского языка может проходить в комфортном для вас темпе. Мы подберём удобный график и в любой момент поможем изменить расписание, сделать перерыв или скорректировать программу.\r\n\r\n\r\n## Сколько длится один урок?\r\n\r\n\r\nДлительность ознакомительной встречи — 30-40 минут, все остальные занятия на курсе английского языка для взрослых длятся 50 минут. \r\n\r\n\r\n\r\n\r\n## Скачайте приложение и занимайтесь в любой обстановке\r\n\r\n\r\n- Тренажёры и упражнения\r\n- Занятия с учителем\r\n- Доступ к домашке', metadata={}),
#  'de6fd74f-3978-4a39-997a-a3841c34b3a1': Document(page_content='## 10 причин учиться онлайн в Skyeng\r\n\r\n\r\nС нами вы будете уверенно использовать новый язык в любой ситуации\r\n\r\n\r\n1. Сразу начнём с разговорной практики\r\n   - С первого урока мы будем говорить на английском. Не стесняйтесь, даже если вам кажется, что ваших знаний или уровня недостаточно. Преподаватель вам поможет: задаст наводящий вопрос, подскажет слово, объяснит правило.\r\n   - Для каждого урока мы подготовили около 25 вопросов для обсуждения. Так вам будет легче преодолеть языковой барьер. Вместе с преподавателем вы обсудите эмоциональный интеллект, гастротуризм, биохакинг и другие современные темы — и придёте сначала к хорошим, а затем к отличным результатам.\r\n2. Сфокусируемся на том, что вам интересно\r\n3. Своя образовательная экосистема\r\n4. Собственная интерактивная платформа\r\n5. Соответствие международным стандартам\r\n6. 15 000+ внимательных преподавателей\r\n7. Гибкое расписание\r\n8. Подготовка к IELTS и другим экзаменам\r\n9. Английский для работы\r\n10. Английский для всей семьи', metadata={}),
#  '6ee4c67e-39b7-4ed6-81b5-aed5e5af34c9': Document(page_content='# Курсы английского языка с нуля\r\n\r\n\r\nНачните изучать английский с нуля! Расширьте словарный запас, разберитесь в грамматике и научитесь понимать живую речь на слух вместе с нами. Это поможет свободно общаться с людьми, читать и писать на английском.\r\n\r\n\r\n## Запишитесь на бесплатный урок\r\n\r\n\r\nОставьте заявку, и мы перезвоним, чтобы узнать, когда вам будет удобно познакомиться со Skyeng.\r\n\r\n\r\n## Сделайте первые шаги, если никогда не учили язык\r\n\r\n\r\n1. Начните читать и писать на английском\r\n2. Общайтесь с иностранцами на простые темы\r\n\r\n\r\n\r\n\r\n## Программа обучения английскому с нуля\r\n\r\n\r\n44 онлайн-урока  \r\n9 тематических модулей\r\n\r\n\r\n1. Nice to meet you\r\n\r\n\r\nВы узнаете: как называются страны мира и города, как произнести свое имя, описать себя и других людей.\r\n\r\n\r\nВы научитесь: представляться собеседнику и задавать ему ответные вопросы.\r\n\r\n\r\nВы сможете: познакомиться с человеком — узнать его имя, родную страну, адрес, номер телефона и рассказать то же самое о себе.\r\n\r\n\r\n2. Family and friends', metadata={}),
#  'd070e137-2d02-46bb-98e0-be66bc401ecf': Document(page_content='Вы узнаете: как можно по-английски назвать разных членов семьи и описать свои чувства.\r\n\r\n\r\nВы научитесь: спрашивать собеседника о его семье, обсуждать с ним домашних животных и подбирать питомцев, которые подходит вам по темпераменту.\r\n\r\n\r\nВы сможете: рассказать о членах вашей семьи, описать их привычки и характеры.\r\n\r\n\r\n3. Job\r\n\r\n\r\nВы узнаете: как называются предметы, которыми мы пользуемся каждый день.\r\n\r\n\r\nВы научитесь: описывать содержимое вашей сумочки, спрашивать домочадцев о потерянных вещах и выбирать предметы, которые стоит взять с собой в путешествие.\r\n\r\n\r\nВы сможете: рассказать собеседнику о том, какие вещи (и не только) принадлежат вам или членам вашей семьи.\r\n\r\n\r\n4. Travel\r\n\r\n\r\nВы узнаете: как называются некоторые профессии, какими словами описать ваши ежедневные дела и что необычного делают знаменитости каждый день.\r\n\r\n\r\nВы научитесь: рассказывать о домашних обязанностях членов вашей семьи и спрашивать собеседника, как это принято делать у него.', metadata={}),
#  'a6b78228-a998-48d5-bf99-bf365f20f700': Document(page_content='Вы сможете: узнать, как искать друзей в социальных сетях и как описывать собеседнику ваш темперамент.\r\n\r\n\r\n5. Everyday life\r\n\r\n\r\nВы узнаете: как в английском языке называются дни недели, праздники и хобби.\r\n\r\n\r\nВы научитесь: рассказывать, как вы любите проводить время в хорошую и плохую погоду, а также расспрашивать об этом собеседника.\r\n\r\n\r\nВы сможете: поделиться, какие праздники принято отмечать в вашей семье, когда у вас день рождения и какому хобби вы отдаете свободное время.\r\n\r\n\r\n6. On an island in Scotland\r\n\r\n\r\nВы узнаете: какими словами можно рассказать о комнатах и мебели в квартире.\r\n\r\n\r\nВы научитесь: обсуждать аренду квартиры с риелтором и членами семьи, общаться с продавцами в магазинах мебели.\r\n\r\n\r\nВы сможете: пригласить собеседника на новоселье и провести устный рум-тур по вашей любимой комнате в доме.\r\n\r\n\r\n7. Hobby and plans', metadata={}),
#  '960af9d7-93b9-45f1-8b67-6285406ca836': Document(page_content='Вы узнаете: какие слова помогут вам рассказать о любимой еде, как называются разные магазины и чем рацион спортсмена отличается от меню человека, который зарабатывает умственным трудом.\r\n\r\n\r\nВы научитесь: составлять шоп-листы на английском и обсуждать список покупок.\r\n\r\n\r\nВы сможете: посоветовать собеседнику блюдо или наряд, научить бабушку заказывать товары онлайн и пообщаться с продавцом в магазине.\r\n\r\n\r\n8. People Around You\r\n\r\n\r\nВы узнаете: как называть даты, а ещё несколько новых полезных глаголов.\r\n\r\n\r\nВы научитесь: рассказывать о событиях, которые перевернули вашу жизнь.\r\n\r\n\r\nВы сможете: поговорить с собеседником о том, как впервые встретили важного для вас человека, и обсудить с ним необычные мировые рекорды.\r\n\r\n\r\n9. So Many Plans\r\n\r\n\r\nВы узнаете: слова, которые помогут рассказать о планах на день по-английски и описать отпуск вашей мечты.\r\n\r\n\r\nВы научитесь: приглашать друзей на вечеринку, вежливо отказываться от приглашения и расспрашивать о том, что пропустили.', metadata={}),
#  '803b655f-de1b-4a8a-ab7c-4c672220d3d1': Document(page_content='Вы сможете: рассказывать туристам о вашем родном городе и его знаковых местах, обсуждать любимые активности во время отпуска и рассказывать о дне, когда все пошло не по плану.\r\n\r\n\r\n\r\n\r\n## Пройдите первый урок бесплатно\r\n\r\n\r\nНа нем мы познакомимся, проверим уровень языка и покажем, как проходят занятия на онлайн-платформе.\r\n\r\n\r\n## Стоимость Курсов английского языка с нуля\r\n\r\n\r\nДополнительные уроки бесплатно\r\n1 месяц участия в разговорных клубах\r\n\r\n\r\n1. 128 + 3 урока\r\n\r\n\r\n950 ₽ за урок  \r\n\r\n\r\n2. 96 + 3 урока\r\n\r\n\r\n990 ₽ за урок  \r\n\r\n\r\n3. 64 + 3 урока\r\n\r\n\r\n1 090 ₽ за урок  \r\n\r\n\r\n4. 32 + 3 урока\r\n\r\n\r\n1 240 ₽ за урок  \r\n\r\n\r\n5. 16 + 2 урока\r\n\r\n\r\n1 490 ₽ за урок  \r\n\r\n\r\n6. 8 + 1 урок\r\n\r\n\r\n1 590 ₽ за урок  \r\n\r\n\r\n7. 4 + 1 урок\r\n\r\n\r\n1 890 ₽ за урок  \r\n\r\n\r\n## Начните говорить по-английски на первом занятии, и через 3–5 месяцев вы будете готовы общаться с иностранцами', metadata={}),
#  '0884745c-bcce-4cd4-af4b-b210df44d93c': Document(page_content='Ваш прогресс зависит от количества уроков. Мы советуем заниматься 3 раза в неделю, чтобы выжать из обучения максимум. С интерактивными упражнениями учиться веселее. А наши преподаватели разговорят любого.\r\n\r\n\r\n## На уроках английского языка с нуля вы научитесь:\r\n\r\n\r\n1. Представляться\r\n2. Рассказывать о себе, родственниках и друзьях\r\n3. Узнавать больше о собеседнике\r\n4. Обсуждать еду, работу и путешествия\r\n\r\n\r\n## Преимущества Skyeng Premium\r\n\r\n\r\n### Пакеты уроков\r\n\r\n\r\n1. 128 + 3 урока\r\n\r\n\r\n1 290 ₽ за урок  \r\n\r\n\r\n2. 96 + 3 урока\r\n\r\n\r\n1 350 ₽ за урок  \r\n\r\n\r\n3. 64 + 3 урока\r\n\r\n\r\n1 550 ₽ за урок  \r\n\r\n\r\n4. 32 + 3 урока\r\n\r\n\r\n1 850 ₽ за урок  \r\n\r\n\r\n5. 16 + 2 урока\r\n\r\n\r\n1 990 ₽ за урок  \r\n\r\n\r\n6. 8 + 1 урок\r\n\r\n\r\n2 350 ₽ за урок  \r\n\r\n\r\n7. 4 + 1 урок\r\n\r\n\r\n2 690 ₽ за урок  \r\n\r\n\r\n\r\n\r\n\r\n\r\n## Что еще нужно купить, чтобы учиться на курсе?', metadata={}),
#  '7999edf3-2b1b-4c89-9b74-29582079242f': Document(page_content='Все необходимое для занятий мы уже собрали на интерактивной платформе. Вам нужно будет только приготовить веб-камеру, микрофон, стабильный интернет и устройство, на которым вы будете заниматься. Подойдут компьютер, смартфон или планшет.\r\n\r\n\r\n## Что делать, если я не могу прийти на урок?\r\n\r\n\r\nНичего страшного, такое бывает! В Skyeng студенты могут бесплатно переносить занятия на другой день и время. Нужно только сообщить об этом учителю английского языка за 8 часов, чтобы он успел перестроить свое расписание и не потерял время. Это можно сделать в личном кабинете.\r\n\r\n\r\n## Мало свободного времени. Боюсь, что не буду успевать заниматься.\r\n\r\n\r\nКаждый студент Skyeng может составить гибкое расписание — мы не ограничиваем вас жесткими рамками. Вы можете выбрать дни недели и время, когда будет удобно заниматься. Это можно делать вечером после работы, в обед или утром — тогда, когда это будет удобно. Если вы уже построили график, но планы поменялись, расписание можно переделать.', metadata={}),
#  '9344542c-0986-47f4-bead-24f31a9a363b': Document(page_content='Кстати, если вы хотите отдохнуть от занятий или временно не можете приходить на уроки, в личном кабинете можно оформить отпуск. Он на время заморозит ваш прогресс. После вы сможете вернуться к занятиям, когда будете готовы. Мы подождем, и уроки не сгорят.\r\n\r\n\r\n## Сколько длится один урок?\r\nОдно занятие в Skyeng длится 50 минут.\r\n\r\n\r\n## Кто будет вести курс?\r\n\r\n\r\nВы будете заниматься на курсе английского языка с одним из наших учителей — опытных педагогов. Выбрать учителя можно самому — почитайте о них больше на странице «Преподаватели» и начните учиться с тем, кто вам ближе.\r\n\r\n\r\nЕсть и второй вариант. Расскажите нам о том, что вы цените в учителе, и мы сами найдем подходящего по вашим критериям. А если что-то пойдет не так, его можно будет заменить. Это легко сделать в личном кабинете.\r\n\r\n\r\n## Что еще входит в цену курса, кроме самого курса?', metadata={}),
#  '39223a08-9bd8-4eb8-9787-34be09e53a35': Document(page_content='Вместе с курсами уроков каждый студент может бесплатно практиковать английский в разговорном клубе. Также у нас есть бесплатное приложение. В нем можно просматривать материалы уроков, учить слова на тренажере, проходить видеопрактику и делать много других полезностей. Все это доступно в любое время 24/7.\r\n\r\n\r\n## Я уже начинал учить английский язык и бросил, потому что было скучно. На курсе будут те же задания, что и в старых учебниках?\r\n\r\n\r\nНет! Мы составили программу так, чтобы увлечь вас. На уроках в Skyeng мы учим язык на современных темах и упражнениях, которые будут полезны в жизни. Например, наши студенты обсуждают с преподавателем эмоциональный интеллект, биохакинг, soft skills, гастротуризм и многое другое. Никаких школьных тем — только тренды и полезные навыки, которые интересно изучать взрослым. \r\n\r\n\r\n\r\n\r\n## Чему вы научитесь на курсе английского с нуля', metadata={}),
#  '67474668-dcb6-4c80-84af-9353b99744f4': Document(page_content='Программа для взрослых New General English состоит из 9 тематических блоков. Каждый из них погрузит вас в жизненные ситуации и научит пользоваться английским. Например, чтобы познакомиться с собеседником, обменяться телефонами или снять квартиру. Мы наполнили уроки интерактивными заданиями, которые помогут прокачать все навыки языка и перейти с уровня Beginner на Elementary:\r\n\r\n\r\n1. Аудирование: научитесь понимать на слух несложные тексты, фразы, имена, названия стран и городов, отдельные простые слова.\r\n2. Лексика: запомните, как называются члены семьи, профессии, дни недели, числа до 100, еда и напитки, иностранные географические названия и простые предметы.\r\n3. Говорение: сможете говорить на повседневные темы: распорядок дня, работа, семья, шопинг и т. д.\r\n4. Грамматика: научитесь строить несложные предложения в настоящем, прошлом и будущем времени, чтобы рассказать о себе, своих хобби и вкусах, планах на отпуск и на день, а также задавать вопросы собеседнику.', metadata={}),
#  'a8308080-fd73-4fd4-82eb-792ed2015653': Document(page_content='5. Чтение и письмо: научитесь делать все вышеперечисленное в переписке, чтобы общаться с иностранцами в соцсетях.\r\n\r\n\r\nПознакомьтесь с онлайн-платформой на вводном уроке! Мы поможем вам найти цель и учителя, с которым будет комфортно идти к ней.\r\n\r\n\r\n# Курсы английского языка для начинающих\r\n\r\n\r\nОбучение английского языка для начинающих позволяет начать понимать иностранную речь, читать, грамотно писать и бегло разговаривать. Здесь вы познакомитесь с грамматическими правилами уровней Beginner и Elementary, выучите формы глаголов.\r\n\r\n\r\nЗапишитесь на вводный урок!\r\n\r\n\r\nПри оплате обучения в день обращения — 2 урока в подарок!\r\n\r\n\r\n\r\n\r\n## Программа уроков по английскому языку для начинающих\r\n\r\n\r\n- 48 онлайн-уроков\r\n- 12 тематических модулей\r\n\r\n\r\n1. People\r\n\r\n\r\nВы узнаете: о разных типах семей, поймете, как лучше рассказывать о себе при знакомстве.\r\n\r\n\r\nВы научитесь: говорить о себе и других людях: описывать не только внешность, но и характер, привычки.', metadata={}),
#  'c7fd45a4-e90c-4d34-8e2d-4c35be4e709e': Document(page_content='Вы сможете: представиться в незнакомой компании и поговорить не только о себе.\r\n\r\n\r\nУроки в разделе:\r\nNice to meet you\r\nMore about me\r\nFamily exchange\r\nPeople’s world (опционально)\r\n\r\n\r\n2. Routine and fun\r\n\r\n\r\nВы узнаете: где работают супергерои, чем ежедневная рутина знаменитостей отличается от вашей и как это — работать в международной корпорации.\r\n\r\n\r\nВы научитесь: рассказывать о людях разных профессий, хороших и не очень днях, плюсах и минусах больших компаний.\r\n\r\n\r\nВы сможете: нафантазировать себе самый лучший день, представить себя карьерным консультантом.\r\n\r\n\r\nУроки в разделе:\r\nWhere do superheroes work?\r\nDaily routine\r\nLet’s have fun together!\r\nCorporate culture (опционально)\r\n\r\n\r\nПромежуточный контроль знаний\r\n\r\n\r\n3. Where I live\r\n\r\n\r\nВы узнаете: что бардак случается у всех, выясните, как выглядят типовые квартиры и дома в разных странах.\r\n\r\n\r\nВы научитесь: создавать дома уют и рассказывать о своей комнате.\r\n\r\n\r\nВы сможете: описать свое идеальное жилье.\r\n\r\n\r\nУроки в разделе:\r\nWhere I live', metadata={}),
#  'a2a424a0-1e9b-4a5a-b83c-531283fd9ac1': Document(page_content='What a mess!\r\nMaking it cosy\r\nA room for two (опционально)\r\n\r\n\r\n4. Free time\r\n\r\n\r\nВы узнаете: что делает людей счастливыми.\r\n\r\n\r\nВы научитесь: говорить о предпочтениях в спорте, необычных хобби и хороших местах для отдыха.\r\n\r\n\r\nВы сможете: составить список вещей, которые делают вас счастливыми, основать клуб по интересам, разобраться в плюсах и минусах занятий спортом, а еще понять, как ничего не делать и получать от этого удовольствие.\r\n\r\n\r\nУроки в разделе:\r\nOn cloud nine\r\nJoin a group!\r\nNo limit\r\nThe art of doing nothing (опционально)\r\n\r\n\r\nПромежуточный контроль знаний\r\n\r\n\r\n5. Food\r\n\r\n\r\nВы узнаете: как работают ресторанные критики, какие национальные блюда стоит попробовать и что такое guilty pleasure.\r\n\r\n\r\nВы научитесь: описывать любимую еду, заказывать блюда в ресторане и читать ценники в супермаркетах.\r\n\r\n\r\nВы сможете: составить меню для своего идеального ресторана, выбрать самый полезный перекус и поделиться рецептом.\r\n\r\n\r\nУроки в разделе:\r\nWhat’s in your fridge?\r\nReady to order?\r\nHappy diet', metadata={}),
#  '187a92b5-1a78-4b48-aca3-de8e9e07c51c': Document(page_content='Eating tasty (опционально)\r\n\r\n\r\n6. Past\r\n\r\n\r\nВы узнаете: несколько фактов из жизни известных людей, о забавных и странных совпадениях, которые могут случиться с каждым, о секретах успешных рассказчиков.\r\n\r\n\r\nВы научитесь: рассказывать интересные истории из прошлого.\r\n\r\n\r\nВы сможете: вспомнить смешные случаи из жизни и написать свою историю.\r\n\r\n\r\nУроки в разделе:\r\nBiographies\r\nHistory\r\nOdd coincidences\r\nThe power of storytelling (опционально)\r\n\r\n\r\nПромежуточный контроль знаний\r\nПромежуточный экзамен\r\n\r\n\r\n\r\n\r\n7. Appearance\r\n\r\n\r\nВы узнаете: на что идут актеры для получения роли, можно ли вычислить преступника по внешнему виду и как организовывают модные показы.\r\n\r\n\r\nВы научитесь: описывать внешность людей, рассказывать об одежде и своих предпочтениях в моде.\r\n\r\n\r\nВы сможете: составить свой капсульный гардероб, оценить чужие образы.\r\n\r\n\r\nУроки в разделе:\r\nHow do I look?\r\nClothes\r\nWorld fashion\r\nWanted! (опционально)\r\n\r\n\r\n8. Nature', metadata={}),
#  '4df5ff71-52b9-4d87-bf2c-62a500db2774': Document(page_content='Вы узнаете: о погоде в разных местах планеты, об удивительных животных и их повадках.\r\n\r\n\r\nВы научитесь: рассказывать о питомцах, понимать метеопрогноз, рассуждать о погоде за рамками «The weather is fine».\r\n\r\n\r\nВы сможете: описывать эмоции, говорить о погоде.\r\n\r\n\r\nУроки в разделе:\r\nLet it snow!\r\nWeather forecast\r\nGoing to a zoo\r\n70 percent of the Earth (опционально)\r\n\r\n\r\nПромежуточный контроль знаний\r\n\r\n\r\n9. Shopping\r\n\r\n\r\nВы узнаете: как выгодно ходить за покупками, что обычно покупают люди в «Черную пятницу».\r\n\r\n\r\nВы научитесь: разговаривать с продавцом-консультантом, давать советы о подарках, помогать другим ориентироваться в магазинах.\r\n\r\n\r\nВы сможете: делать покупки за границей, сравнивать качество и цены товаров в разных магазинах.\r\n\r\n\r\nУроки в разделе:\r\nAt a shop\r\nCan I see those?\r\nBlack Friday\r\nBest present ever!\r\n\r\n\r\n10. Health\r\n\r\n\r\nВы узнаете: как ответить на знаменитый вопрос «Are you ok?», попросить помощи или предложить ее.', metadata={}),
#  'ddae9205-23f9-497d-ae81-bddbcdc9bf1c': Document(page_content="Вы научитесь: записываться к врачу, рассказывать о своих симптомах, понимать чужие медицинские проблемы.\r\n\r\n\r\nВы сможете: вызвать скорую и оказать первую помощь.\r\n\r\n\r\nУроки в разделе:\r\nMedical problems\r\nDoctor's advice\r\nAre you ok?\r\nNot a disease!\r\n\r\n\r\nПромежуточный контроль знаний\r\n\r\n\r\n11. Holidays\r\n\r\n\r\nВы узнаете: почему и тревел-блогеры плачут, вспомните, что отпуск — это не только солнечные ванны и запишете в список будущих путешествий.\r\n\r\n\r\nВы научитесь: рассказывать об отпуске и узнавать про это у других.\r\n\r\n\r\nВы сможете: примерить на себя жизнь трэвел-блогера и помечтать об идеальном отдыхе.\r\n\r\n\r\nУроки в разделе:\r\nThe best place I've ever seen\r\nNot only sunbathing\r\n4 places to see before you die\r\nWork or travel?\r\n\r\n\r\n12. City\r\n\r\n\r\nВы узнаете: почему лучше выбирать самолет. Или корабль. Нет, поезд. Может, вообще автобус? Кажется, на машине будет удобнее... Или все же самолет?\r\n\r\n\r\nВы научитесь: читать городские знаки, узнавать и объяснять путь, держать себя в руках и понимать правила разных стран.", metadata={}),
#  '94cc02fa-3a12-40e5-b2c1-9692844bedcb': Document(page_content='Вы сможете: купить билет на автобус, самолет, пароход или любой другой вид транспорта.\r\n\r\n\r\nУроки в разделе:\r\nHow can I get to the hotel\r\nAir or water?\r\nYou must behave!\r\nCan I have a single to London?\r\n\r\n\r\nПромежуточный контроль знаний\r\nПодготовка к экзамену\r\nФинальный экзамен курса\r\n\r\n\r\n\r\n\r\n## Пройдите первый урок бесплатно\r\n\r\n\r\nПознакомимся, проверим уровень языка, покажем, как проходят занятия на платформе.\r\n\r\n\r\n## Получите бонусы от Skyeng при оплате нескольких занятий\r\n\r\n\r\nДополнительные уроки бесплатно  \r\n1 месяц участия в разговорных клубах\r\n\r\n\r\n1. 128 + 3 урока  \r\n   950\u202f₽ за урок  \r\n\r\n\r\n2. 96 + 3 урока  \r\n   990\u202f₽ за урок  \r\n\r\n\r\n3. 64 + 3 урока  \r\n   1\u202f090\u202f₽ за урок  \r\n\r\n\r\n4. 32 + 3 урока  \r\n   1\u202f240\u202f₽ за урок  \r\n\r\n\r\n5. 16 + 2 урока  \r\n   1\u202f490\u202f₽ за урок  \r\n\r\n\r\n6. 8 + 1 урок  \r\n   1\u202f590\u202f₽ за урок  \r\n\r\n\r\n7. 4 + 1 урок  \r\n   1\u202f890\u202f₽ за урок  \r\n\r\n\r\n## Прокачайте ваш английский для общения на любые темы', metadata={}),
#  '7ea034dd-721f-45a1-baa6-b640a15e2451': Document(page_content='Прогресс зависит от интенсивности занятий — мы рекомендуем заниматься 3 раза в неделю. Интерактивные задания сделают урок увлекательнее. А наши учителя разговорят любого.\r\n\r\n\r\n## На уроках английского языка для начинающих вы научитесь\r\n\r\n\r\n- описывать себя, свой дом и любимую еду;\r\n- говорить о семье и друзьях;\r\n- обсуждать свои хобби, работу и отпуск.\r\n\r\n\r\n\r\n\r\n## Преимущества Skyeng Premium\r\n\r\n\r\n### Пакеты уроков\r\n\r\n\r\n1. 128 + 3 урока  \r\n   1\u202f290\u202f₽ за урок  \r\n\r\n\r\n\r\n\r\n2. 96 + 3 урока  \r\n   1\u202f350\u202f₽ за урок  \r\n\r\n\r\n\r\n\r\n3. 64 + 3 урока  \r\n   1\u202f550\u202f₽ за урок  \r\n\r\n\r\n\r\n\r\n4. 32 + 3 урока  \r\n   1\u202f850\u202f₽ за урок  \r\n\r\n\r\n\r\n\r\n5. 16 + 2 урока  \r\n   1\u202f990\u202f₽ за урок  \r\n\r\n\r\n\r\n\r\n6. 8 + 1 урок  \r\n   2\u202f350\u202f₽ за урок  \r\n\r\n\r\n\r\n\r\n7. 4 + 1 урок  \r\n   2\u202f690\u202f₽ за урок  \r\n\r\n\r\n\r\n\r\n\r\n\r\n## Что еще нужно купить, чтобы учиться на курсе?', metadata={}),
#  'ff62f307-0656-42b3-96be-639cd3f6932f': Document(page_content='Все необходимое для занятий мы уже собрали на интерактивной платформе. Вам нужно будет только приготовить веб-камеру, микрофон, стабильный интернет и устройство, на которым вы будете заниматься. Подойдут компьютер, смартфон или планшет.\r\n\r\n\r\n## Что делать, если я не могу прийти на урок?\r\n\r\n\r\nНичего страшного, такое бывает! В Skyeng студенты могут бесплатно переносить занятия на другой день и время. Нужно только сообщить об этом учителю английского языка за 8 часов, чтобы он успел перестроить свое расписание и не потерял время. Это можно сделать в личном кабинете.\r\n\r\n\r\n## Мало свободного времени. Боюсь, что не буду успевать заниматься.\r\n\r\n\r\nКаждый студент Skyeng может составить гибкое расписание — мы не ограничиваем вас жесткими рамками. Вы можете выбрать дни недели и время, когда будет удобно заниматься. Это можно делать вечером после работы, в обед или утром — тогда, когда это будет удобно. Если вы уже построили график, но планы поменялись, расписание можно переделать.', metadata={}),
#  '126e264b-0855-4559-a642-1e027b925757': Document(page_content='Кстати, если вы хотите отдохнуть от занятий или временно не можете приходить на уроки, в личном кабинете можно оформить отпуск. Он на время заморозит ваш прогресс. После вы сможете вернуться к занятиям, когда будете готовы. Мы подождем, и уроки не сгорят.\r\n\r\n\r\n## Сколько длится один урок?\r\n\r\n\r\nОдно занятие в Skyeng длится 50 минут.\r\n\r\n\r\n## Кто будет вести курс?\r\n\r\n\r\nВы будете заниматься на курсе английского языка с одним из наших учителей — опытных педагогов. Выбрать учителя можно самому — почитайте о них больше на странице «Преподаватели» и начните учиться с тем, кто вам ближе.\r\n\r\n\r\nЕсть и второй вариант. Расскажите нам о том, что вы цените в учителе, и мы сами найдем подходящего по вашим критериям. А если что-то пойдет не так, его можно будет заменить. Это легко сделать в личном кабинете.\r\n\r\n\r\n## Что еще входит в цену курса, кроме самого курса?', metadata={}),
#  '58e4aad6-78e6-402b-8977-f9fd184c25fe': Document(page_content='Вместе с курсами уроков каждый студент может бесплатно практиковать английский в разговорном клубе. Также у нас есть бесплатное приложение. В нем можно просматривать материалы уроков, учить слова на тренажере, проходить видеопрактику и делать много других полезностей. Все это доступно в любое время 24/7.\r\n\r\n\r\n## Я уже начинал учить английский язык и бросил, потому что было скучно. На курсе будут те же задания, что и в старых учебниках?\r\n\r\n\r\nНет! Мы составили программу так, чтобы увлечь вас. На уроках в Skyeng мы учим язык на современных темах и упражнениях, которые будут полезны в жизни. Например, наши студенты обсуждают с преподавателем эмоциональный интеллект, биохакинг, soft skills, гастротуризм и многое другое. Никаких школьных тем — только тренды и полезные навыки, которые интересно изучать взрослым. \r\n\r\n\r\n\r\n\r\n## О курсе английского языка для начинающих', metadata={}),
#  '11c6cccf-1120-4065-81a4-733c54f5671e': Document(page_content='Курс New General English поможет студентам с уровнем Elementary поставить четкую цель и улучшить навыки до Pre-Intermediate. Мы разработали программу так, чтобы охватить весь спектр знаний и показать, как начать пользоваться ими в реальной жизни. Для этого наши методисты подготовили задания и теорию на темы, полезные взрослому человеку.\r\n\r\n\r\nВ Skyeng вы научитесь:\r\n\r\n\r\n- знакомиться, рассказывать о себе и спрашивать о собеседнике;\r\n- говорить о профессиях — своей и других людей;\r\n- делать покупки онлайн и офлайн в магазине на английском;\r\n- обсуждать плюсы и минусы профессионального спорта;\r\n- ориентироваться в незнакомом городе по знакам на улице;\r\n- общаться с доктором на приеме в больнице и многому другому.\r\n\r\n\r\nУ курса для начинающих гибкая структура. Это значит, что в программе есть обязательные и необязательные уроки. Вы можете решить, какие из них проходить, а какие нет, вместе с учителем. Он поможет составить ваш индивидуальный путь к цели.\r\n\r\n\r\n## 5 причин учить английский язык в Skyeng', metadata={}),
#  '6f354cac-6cd8-45dc-92b2-f7cd12a8b08c': Document(page_content='### Бесплатный вводный урок\r\n\r\n\r\nМы можем познакомиться еще до обучения. Для этого достаточно оставить заявку и записаться на вводное занятие. Там можно узнать, как работает онлайн-платформа, и пройти тест на уровень языка. После этого к вам подключится методист. Он поможет определить цель, подобрать нужный курс и ответит на вопросы о школе.\r\n\r\n\r\n### 80% разговорной практики на занятии\r\n\r\n\r\nСтуденты Skyeng начинают говорить на английском уже с первого занятия и дальше практикуются большую часть времени. Это заслуга коммуникативной методики. Ее суть в том, чтобы разговорить ученика с первых минут занятия и помочь ему переступить языковой барьер. Так вы сможете получать реальные навыки и учиться общению, вместо того чтобы быть теоретиком.\r\n\r\n\r\n### Опытные преподаватели', metadata={}),
#  '55f5b667-1eab-47f0-a1a0-94e121be9bee': Document(page_content='Преподаватели Skyeng — это опытные педагоги, которые знают, как разговорить студента. Только 5 из 100 кандидатов проходят отбор, поэтому мы спокойны за качество их уроков. Чтобы и дальше держать эту планку высокой, наши педагоги обучаются каждый год. А еще с ними можно поговорить на любую интересную вам тему на английском.\r\n\r\n\r\n### Все функции — в мобильном приложении\r\n\r\n\r\nВ приложении Skyeng мы собрали все, что поможет вам управлять обучением. Здесь вы можете видеть статистику по пройденным темам и следить за своим прогрессом. 24/7 в приложении доступны тренировки и словари. В нем же можно поменять расписание, перенести урок или взять отпуск на месяц. А если понадобится помощь, можно связаться с техподдержкой или учителем английского.\r\n\r\n\r\n# Курсы английского языка для продолжающих', metadata={}),
#  '9bfdcbbb-8086-49f6-9077-5e88e1026b21': Document(page_content='Курс позволяет продвинуться дальше в изучении английского языка. На занятиях можно познакомиться с новыми словами и грамматикой уровня Pre-intermediate. Уроки позволят развить имеющиеся навыки: аудирование, чтение, письмо и говорение.\r\n\r\n\r\n1. Избавьтесь от акцента\r\n\r\n\r\n2. Станьте лучше воспринимать язык на слух\r\n\r\n\r\n3. Изучите грамматические структуры\r\n\r\n\r\n\r\n\r\n## Программа курса английского Pre-Intermediate\r\n\r\n\r\n60 онлайн-уроков  \r\n15 тематических модулей\r\n\r\n\r\n1. First Impression\r\n\r\n\r\nВы узнаете: как произвести хорошее первое впечатление. Научитесь заполнить профиль в социальной сети и выясните, к каким популярным хобби присмотреться.\r\n\r\n\r\nВы научитесь: описывать характер — свой и друзей, рассказывать об увлечениях и привычках.\r\n\r\n\r\nВы сможете: завести беседу с англоговорящими людьми.\r\n\r\n\r\n### Уроки в разделе:\r\n\r\n\r\n1. A person in three words\r\n2. First impressions\r\n3. Are you a hobbyist?\r\n4. Find me online (опционально)\r\n\r\n\r\n## 2. Sport or not?\r\n\r\n\r\n## 3. That’s the story!\r\n\r\n\r\n## 4. People around you', metadata={}),
# ...
#  '95015a15-5227-436e-abb1-e5a39328d5d6': Document(page_content='Мы будем рядом 24/7, чтобы помочь настроить курс: перенести урок, составить расписание и прочее.\r\n\r\n\r\n### Развитие вне уроков\r\n\r\n\r\nС premium-курсом вы сможете участвовать в закрытом разговорном клубе. А еще за вашими успехами будет следить методист.\r\n\r\n\r\n## Тренируйте новые навыки на практике\r\n\r\n\r\n1. Ломайте любые языковые барьеры\r\n2. Учите язык быстрее и повышайте свой уровень\r\n3. Научим свободно говорить, писать и думать на английском\r\n\r\n\r\n\r\n\r\n\r\n\r\n## Погрузитесь в языковую среду с первого занятия\r\n\r\n\r\n### Индивидуальный подход\r\n\r\n\r\nСоставим программу, подберем темы уроков, упражнения и темп занятий конкретно под ваш запрос.\r\n\r\n\r\nИспользуйте английский сразу, как захотите — а мы создадим для этого комфортные условия\r\n\r\n\r\n### Разговорные клубы\r\n\r\n\r\nПроводим 10+ клубов на выбор каждый день, чтобы вы прокачали речь и нашли друзей с такими же целями и интересами.\r\n\r\n\r\nЧем больше вы будете использовать язык, тем быстрее его выучите\r\n\r\n\r\n\r\n\r\n### Персональное сопровождение 24/7', metadata={}),
#  'f3ba4748-6506-454b-8533-0d9a6ca6460c': Document(page_content='- Если планы поменялись, занятие можно перенести за 4 часа до старта без потери оплаты\r\n- На связи в любое время в личном кабинете, приложении, Telegram и WhatsApp\r\n- Поможет перенести урок, сменить расписание или преподавателя\r\n\r\n\r\n### Тренируйтесь на разговорах с иностранцами\r\n\r\n\r\n3 занятия в Talks в подарок\r\n\r\n\r\n- Познакомиться с разными людьми и культурами.\r\n- 15-минутные разговоры с преподавателями со всего мира\r\n- Найдем собеседника за 1-2 минуты\r\n- Более 300 готовых тем, если не знаете, о чем говорить\r\n- Обратная связь от опытного преподавателя\r\n\r\n\r\n### Результаты вы увидите сами\r\n\r\n\r\n#### Скрининг-тест\r\n\r\n\r\nПроверьте состояние всех 8 навыков на старте — и проходите тест каждые полгода, чтобы отслеживать прогресс.\r\n\r\n\r\n#### Виджет прогресса\r\n\r\n\r\nПокажем в реальном времени, как каждое упражнение приближает вас к следующему языковому уровню.\r\n\r\n\r\n\r\n\r\n## Стоимость занятий\r\n\r\n\r\n1. 128 +3 урока — 1\u202f290\u202f₽ за урок\r\n2. 96 +3 уроков — 1\u202f350\u202f₽ за урок\r\n3. 64 +3 уроков — 1\u202f550\u202f₽ за урок', metadata={}),
#  '826fd7fe-7a90-4b1f-87d4-3a37f0dcea40': Document(page_content='4. 32 +3 урок — 1\u202f850\u202f₽ за урок\r\n5. Выгода 28\u202f₽ — 16 +2 урок — 1\u202f990\u202f₽ за урок\r\n6. 8 +1 урок — 2\u202f350\u202f₽ за урок\r\n7. 4 +1 урок — 2\u202f690\u202f₽ за урок\r\n\r\n\r\n\r\n\r\n\r\n\r\n# Самостоятельные занятия английским\r\n\r\n\r\n## Ситуации\r\nСценарии из реальной жизни, с которыми вы будете готовы использовать язык на практике\r\n\r\n\r\n## Аудиокниги\r\nБестселлеры на языке оригинала\r\n\r\n\r\n## Видеопрактика\r\nАктуальные видео и упражнения после\r\n\r\n\r\n## Тренажёр слов\r\nНе просто словарь, а повторение, трекинг и поиск новых слов\r\n\r\n\r\n# Начать заниматься\r\n\r\n\r\n## Изучайте язык в удобном для вас формате\r\n1. Можно развивать аудирование, речь, чтение и письмо одновременно или делать акцент на определенных навыках.\r\n2. Упражнения доступны с любого подключенного к интернету девайса.\r\n3. Темп выбираете только вы — заниматься можно дома, в метро, на прогулке с собакой или во время обеденного перерыва.\r\n\r\n\r\n## Освойте язык для любых целей', metadata={}),
#  'ea776fce-3023-4343-a85d-6279e7de30cd': Document(page_content='1. Для общения — провести встречу с иностранными партнерами, заказать столик в ресторане за границей, написать сообщение любимому артисту.\r\n2. Для новых возможностей — получить повышение на работе, поступить в университет, открыть доступ к контенту на языке оригинала.\r\n3. Для того, чтобы провести время с пользой — проходить короткие уроки в метро, на прогулке с собакой, за чашечкой чая.\r\n\r\n\r\n# Форматы обучения\r\n1. Ситуации\r\n2. Аудиокниги\r\n3. Тренажёр слов\r\n4. Видеопрактика\r\n\r\n\r\n## Уже 103 000 учеников прокачивают английский\r\nПо ситуациям, аудиокнигам, видеопрактике и словарю.\r\n\r\n\r\n## Тренируйте произношение\r\nГолосовой ввод ответов в ситуациях и анализ произношения.\r\n\r\n\r\n## Занимайтесь в браузере\r\nИзучайте английский с компьютера, телефона, планшета или любого другого удобного девайса.\r\n\r\n\r\n## Или через приложение\r\nСкачайте мобильное приложение, чтоб иметь возможность обучаться в любое время, где угодно.\r\n\r\n\r\n\r\n\r\n# Открытый бесплатный курс для глухих и слабослышащих от Skyeng и Центра внимания', metadata={}),
#  '9a9fc754-480f-4cc9-ae3f-ec2b3022cea8': Document(page_content='## Учить английский может каждый\r\n\r\n\r\nС помощью курса вы:\r\n1. Легко освоите основы английского\r\n2. Достигнете уровня Low Beginner\r\n3. Начнете применять английский в повседневной жизни\r\n\r\n\r\n## Как устроен курс\r\n\r\n\r\n1. 20 уроков с адаптированными упражнениями и объяснениями на языке жестов\r\n2. Тесты для закрепления материала\r\n\r\n\r\nУроки открываются постепенно до конца лета — раз в 2,5 недели. Мы пришлем имейл с напоминанием.\r\n\r\n\r\nВы проходите курс самостоятельно в любое удобное для вас время.\r\n\r\n\r\nSkyeng и Центр внимания уверены — у каждого человека должна быть возможность изучать английский, чтобы ориентироваться в современном мире и получать информацию.\r\n\r\n\r\n\r\n\r\n\r\n\r\n# Бесплатные курсы по английскому языку\r\n\r\n\r\nСпециально для вас мы собрали все бесплатные уроки, курсы и марафоны в одном месте.\r\n\r\n\r\n## Для начинающих и не только\r\n\r\n\r\n### Леньтенсив: английский для ленивых\r\n\r\n\r\nЗанимайтесь по 15 минут в день с носителем языка. Бесплатно!\r\n\r\n\r\n### Английская грамматика для жизни', metadata={}),
#  '6ef9413e-9cd9-45cd-b68f-30c14b45ad18': Document(page_content='10 дней бесплатных занятий в телеграм-боте, после которых вы легко и уверенно будете применять грамматику в общении.\r\n\r\n\r\n### Получите бесплатно ваш личный план по изучению английского!\r\n\r\n\r\nХотите учить английский, но не знаете, с чего начать?\r\n\r\n\r\n### Сформируйте привычку учить английский\r\n\r\n\r\nБесплатный 15-дневный марафон для тех, кто хочет учиться, но все время откладывает занятия на потом.\r\n\r\n\r\n\r\n\r\n## Самостоятельные занятия английским бесплатно\r\n\r\n\r\n1. Получайте навыки для разных ситуаций из реальной жизни.\r\n2. Развивайте чтение, письмо, говорение и понимание английской речи.\r\n3. Слушайте книги на языке оригинал.\r\n4. Смотрите видео и выполняйте задания.\r\n\r\n\r\n### Начать заниматься\r\n\r\n\r\n### 5 причин самостоятельно учить английский язык в Skyeng\r\n\r\n\r\n1. Тренажеры и задания доступны 24/7.', metadata={}),
#  '9791cfc9-8d84-434b-895e-0dbfc7c379aa': Document(page_content='2. Учите английский бесплатно, онлайн и без ограничений! Вы можете сами построить график занятий и учиться тогда, когда это удобно. Пользоваться материалами, тренажерами и упражнениями можно в любое время дни и ночи. Они с вами навсегда.\r\n3. Учитесь с нуля по нашим материалам.\r\n4. Упражнения для всех навыков.\r\n5. Занимайтесь на любых устройствах.\r\n\r\n\r\n### Совмещайте приятное с полезным\r\n\r\n\r\n\r\n\r\n## Тесты и гайды\r\n\r\n\r\n### Сколько английских слов вы знаете?\r\n\r\n\r\nПроверьте свой словарный запас бесплатно и всего за 8 минут.\r\n\r\n\r\n### Подготовьтесь к собеседованию на английском\r\n\r\n\r\nБесплатный гайд по подготовке к интервью и запись вебинара с HR-экспертом.\r\n\r\n\r\n\r\n\r\n### Зачем вам знать английский?\r\n\r\n\r\nПройдите тест за 5 минут и узнайте, как английский пригодится лично вам.\r\n\r\n\r\n\r\n\r\n## Для детей и взрослых\r\n\r\n\r\n### Учите английский по фильмам и сериалам\r\n\r\n\r\nСкачайте бесплатный PDF-план «Английский по фильмам и сериалам».\r\n\r\n\r\n\r\n\r\n### Любите читать, смотреть видео и узнавать что-то новое?', metadata={}),
#  '714a243c-e148-4389-b009-37ef95da9e64': Document(page_content='План, как заниматься саморазвитием и одновременно учить английский!\r\n\r\n\r\n\r\n\r\n### Помощник по математике, который всегда под рукой!\r\n\r\n\r\nПовторите темы четверти, подготовьтесь к экзаменам с бесплатным PDF-помощником.\r\n\r\n\r\n\r\n\r\n### Определите уровень своего английского\r\n\r\n\r\nВ конце теста пришлем рекомендации, как повысить уровень, и полезные подарки.\r\n\r\n\r\n\r\n\r\n### Easy English\r\n\r\n\r\nВидеоуроки с простыми советами от носителей и практические задания на каждый день. Бесплатно!\r\n\r\n\r\n\r\n\r\n### Узнайте, что мешает вам выучить английский\r\n\r\n\r\nОтветьте на 10 вопросов и получите подарок от Skyeng.\r\n\r\n\r\n\r\n\r\n### Расскажите, как вы совмещаете работу и отдых?\r\n\r\n\r\nПоделитесь своим мнением и получите подарки от школы!\r\n\r\n\r\n\r\n\r\n### Помогите ребенку выбрать профессию\r\n\r\n\r\nПройдите тест и узнайте, какие профессии подходят вашему ребенку.\r\n\r\n\r\n\r\n\r\n### Тест на уровень английского для детей\r\n\r\n\r\nОпределите уровень английского вашего ребенка за 15 минут.\r\n\r\n\r\n\r\n\r\n### Easy English', metadata={}),
#  '5ddca544-b61b-4c1d-bd7d-f23001af5ab2': Document(page_content='Как наконец заговорить на английском? Это легче чем кажется!\r\n\r\n\r\nSkyeng — это самая крупная онлайн-школа в Европе. У нас учатся 300 000+ учеников.\r\n\r\n\r\n\r\n\r\n\r\n\r\n## Что такое вводный урок, и для чего он нужен?\r\n\r\n\r\nПробное занятие в Skyeng — это урок, на котором можно познакомиться с онлайн-платформой и понять, подходит ли вам этот формат. Мы разделили пробное занятие на две части. Первая часть — самостоятельная. В ней вы сможете пройти тест и узнать свой уровень языка. Вторая — разговор с методистом. Он подключится и расскажет о школе все, что вы хотите узнать. А еще методист поможет вам поставить цель, если вы еще ее не сформулировали. Все это бесплатно и ни к чему не обязывает.\r\n\r\n\r\n## Нужно ли покупать курс, чтобы пользоваться тренажерами в мобильном приложении?\r\n\r\n\r\n## Вредно ли изучать английский самостоятельно?\r\n\r\n\r\n\r\n\r\n## Почему стоит учить английский\r\n\r\n\r\nХороший английский открывает перед людьми многие двери. Вот несколько частых причин, почему его учат наши студенты:', metadata={}),
#  '6eb0aa54-55f2-4d02-ab46-a5621262b765': Document(page_content='1. Карьера: чтобы учиться у зарубежных коллег, повышать квалификацию за границей, работать в иностранной компании, посещать международные конференции и выступать на них.\r\n2. Общение: чтобы знакомиться с людьми по всему миру и заводить новых друзей из разных стран.\r\n3. Культура: чтобы наслаждаться музыкой, кино, литературой и другими произведениями искусства в оригинале.\r\n4. Хобби: чтобы находить единомышленников, ездить на тематические мероприятия и развивать навыки.\r\n5. Путешествия: чтобы комфортно чувствовать себя за границей и общаться с местными жителями.\r\n\r\n\r\nВыберите свою цель, и тогда вы уже не захотите бросить обучение на полпути.\r\n\r\n\r\n## О бесплатном курсе английского', metadata={}),
#  '38b6e149-5719-41e3-885d-9b8179fb3b77': Document(page_content='Самоучитель от Skyeng подойдет тем, кто хочет прокачать язык самостоятельно и реально улучшить свои навыки. В нем мы собрали авторские материалы и задания, с которыми можно практиковаться в удобном для вас формате и в любое время. На курсе можно улучшить каждый из основных навыков. Для этого мы добавили в программу разнообразные упражнения:\r\n\r\n\r\n1. Ситуации. Примерьте на себя сценарии из реальной жизни, в которых вам может пригодиться английский. Например, визит к доктору, регистрация в аэропорту, шоппинг и другие.\r\n2. Тренажер слов. Знакомьтесь с новой лексикой и учитесь пользоваться ей в речи. Тренируйте слова из наших подборок и добавляйте туда собственные.\r\n3. Аудиокниги. Учитесь хорошо понимать речь на слух, запоминайте новые слова и добавляйте их в словарь приложения Skyeng.\r\n4. Видеопрактика. Смотрите ролики в разных жанрах и учитесь понимать живую речь с разными акцентами, а после — выполняйте задания.', metadata={}),
#  'c1642f85-e622-47b6-9a66-785574544635': Document(page_content='5. Тренировка произношения. Пользуйтесь голосовым вводом ответов в «Ситуациях», анализируйте ваше произношение и улучшайте его шаг за шагом.\r\n\r\n\r\nВсе это поможет вам хорошо поработать со всеми навыками в комплексе и поднять уровень. В приложении вы можете сами следить за успехами, статистикой пройденных уроков и делать упор на те задания, которые полезны и интересны больше остальных. Так вы сможете создать собственную гибкую программу, подходящую под ваши цели.\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n# Skyeng Talks — разговорная практика с преподавателями со всего мира\r\n\r\n\r\nОт 15 минут. Работаем с 7 до 00 по мск. Подключение за 1-2 минуты.\r\n\r\n\r\nПопробовать Talks\r\n\r\n\r\nСкачать приложение\r\n\r\n\r\n## Преподаватели со всего мира онлайн с 7:00 до 00:00\r\n\r\n\r\n1. Более 300 готовых тем, если не знаете, о чем говорить\r\n2. Обратная связь от опытного преподавателя\r\n3. Более 100 преподавателей со всего мира\r\n\r\n\r\nВыберите того, с кем хотите практиковаться', metadata={}),
#  '3633a908-9e30-4871-9f0f-1b93a1ebad9a': Document(page_content='Поговорят с вами на любую тему, исправят ошибки, поставят произношение, дадут рекомендации по итогу разговора.\r\n\r\n\r\n\r\n\r\n## Говорите о том, что вам интересно\r\n\r\n\r\nЧтобы было не страшно, к нашим темам покажем полезные слова и фразы во время разговора. Для смелых — можно предлагать свои ;)\r\n\r\n\r\n1. Films and series\r\n2. Computer games\r\n3. The paranormal\r\n4. Family and career choice\r\n5. Job interview\r\n6. Facts about the world\r\n7. Challenges\r\n8. Summer is a little life\r\n9. Travelling\r\n10. Local cuisine\r\n11. Sports\r\n12. Restaurant problems\r\n13. Psychology\r\n14. Your favourite series\r\n15. Junk food and healthy lifestyle\r\n16. Your dream home\r\n17. Your neighbours\r\n18. Old Russian films\r\n19. Cats, dogs and other pets\r\n20. Gadget addiction\r\n21. Art\r\n22. Gender Stereotypes\r\n23. Animals\r\n24. Household chores\r\n25. Role-play: Shopping for clothes\r\n26. Bali\r\n27. Japan\r\n28. Hobbies\r\n29. Holiday Movies\r\n30. Thanksgiving Day\r\n\r\n\r\n## Talks поможет\r\n\r\n\r\n1. Заговорить на английском или повысить беглость.', metadata={}),
#  'e6f5c53c-5cc6-437d-803a-8fcdcff5a414': Document(page_content='2. Понимать разные акценты и не бояться любых собеседников.\r\n3. Узнать актуальные слова и говорить на современном английском.\r\n4. Познакомиться с разными людьми и культурами.\r\n\r\n\r\nИ все это – без домашек и упражнений!\r\n\r\n\r\n\r\n\r\n## Кому подойдет?\r\n\r\n\r\n### Начинающим\r\n\r\n\r\nНеобязательно ждать, пока вы дойдете до следующего уровня: чтобы говорить, надо говорить.\r\n\r\n\r\n### Продолжающим\r\n\r\n\r\nПреподаватель обратит внимание на грамматику, разберет идиомы или нюансы произношения.\r\n\r\n\r\n### И даже самым занятым\r\n\r\n\r\nПрактикуйтесь в такси, в перерыве между встречами, вечером после работы.\r\n\r\n\r\n## Начните говорить уверенно всего за 15 минут в день\r\n\r\n\r\n1. Выберите преподавателя или тему  \r\nПо акценту или по интересам. Можно предложить свою тему.\r\n\r\n\r\n2. Общайтесь в течение 15 минут  \r\nЕсли не успели все обсудить, можно продлить разговор.\r\n\r\n\r\n3. Получайте обратную связь и говорите снова  \r\nПреподаватель запишет новые слова в заметки и пришлет фидбек после занятия.\r\n\r\n\r\n## Оплатите и начните Talks сейчас', metadata={}),
#  '8120a09e-78fc-4160-a415-83e8011637c4': Document(page_content='### 600 минут на 3 месяца\r\n\r\n\r\n40 talks  \r\n1 talk = 225\u202f₽  \r\nВыгода 6\u202f610\u202f₽  \r\nОплатить 8\u202f990\u202f₽  \r\n15\u202f600\u202f₽  \r\nВыгодный\r\n\r\n\r\n### 180 минут на 2 месяца\r\n\r\n\r\n12 talks  \r\n1 talk = 333\u202f₽  \r\nВыгода 690\u202f₽  \r\nОплатить 3\u202f990\u202f₽  \r\n4\u202f680\u202f₽  \r\nПопулярный\r\n\r\n\r\n### 15 минут на 1 месяц\r\n\r\n\r\n1 talks  \r\n1 talk = 390\u202f₽  \r\nОплатить 390\u202f₽', metadata={})}

# %% [markdown]
# Пример вектора эмбединга

# %%
# Получаем индекс FAISS из объекта db
# Поле index содержит сам индекс FAISS, который используется для хранения и поиска векторов
index = db.index

# Извлекаем векторы из индекса
# Метод reconstruct_n(start, count) извлекает count векторов, начиная с позиции start
# В данном случае, start = 0 и count = index.ntotal, что означает извлечение всех векторов из индекса
vectors = index.reconstruct_n(0, index.ntotal)

print("Извлеченные векторы:")
print(vectors)
# Out:
# Извлеченные векторы:
# [[-0.0053272  -0.00761123 -0.01140048 ... -0.0023511   0.00261943
#   -0.02162295]
#  [-0.00168443  0.00259457 -0.01246051 ... -0.00478318  0.00445252
#   -0.02543174]
#  [-0.00724445  0.00864432  0.01082475 ... -0.00098136  0.00863142
#   -0.04900167]
#  ...
#  [-0.00077495  0.0106073   0.0114803  ...  0.01189383 -0.00289305
#   -0.04382076]
#  [-0.01318105  0.01266658  0.01172228 ... -0.00130736  0.0020514
#   -0.02967039]
#  [-0.01194039 -0.00646881  0.01079126 ...  0.0018079   0.01459528
#   -0.0295604 ]]

# %% [markdown]
# ## Поиск по базе

# %% [markdown]
# Метод `similarity_search_with_score` - используется для поиска похожих запросу чанков по близости векторов в многомерном пространстве. Пи этом он возвращает оценку схожести документов

# %%
topic = "как у вас происходит обучение?" # вопрос
k = 3 # количество наиболее релевантных чанков

# %%
# Поиск документов, похожих на заданную тему/вопрос
docs_and_scores = db.similarity_search_with_score(topic, k=k)

# Создание содержимого сообщения, объединяя текст найденных документов и добавляя оценку схожести
message_parts = []  # Инициализируем список для хранения частей сообщения
for doc, score in docs_and_scores:
    # Форматируем текст документа с оценкой схожести
    doc_text_with_similarity = f'\n=====================\nОценка схожести: {score:.4f}\n{doc.page_content}\n'
    # Добавляем отформатированный текст в список частей сообщения
    message_parts.append(doc_text_with_similarity)

# Объединяем все части сообщения в одну строку и заменяем все вхождения '\r\n' на пробелы
message_content = re.sub(r'\r\n', ' ', '\n '.join(message_parts))

# Печать чанков и их оценок схожести
print('Чанки:\n ======================================== \n', message_content)
# Out:
# Чанки:
#  ========================================
#
# =====================
# Оценка схожести: 0.2445
# У каждого свой языковой уровень, темп и удобный ему формат обучения. Мы подбираем план обучения под потребности и цели каждого ученика и, самое главное, доводим до результата с помощью проверенной коммуникативной методологии и системы контроля прогресса. Нам важно, чтобы вы начали использовать язык уже с первого занятия!   ## Как мы достигаем эффективного обучения?   1. Наши курсы разработаны лучшими методистами школы с длительным опытом преподавания онлайн и завалидированы иностранными экспертами. 2. Эмоциональный интеллект, теория лени, гастротуризм, цифровой след, рейтинг городов — никаких школьных топиков. Наши уроки построены на темах, о которых говорит весь мир, с упором на использование в реальной жизни. 3. Мы строим учебный план, основываясь на ваших интересах и целях. Мы подбираем самые подходящие методы обучения в зависимости от ваших предпочтений и навыков.
#
#
# =====================
# Оценка схожести: 0.2756
# ## Как проходят занятия на платформе   1. Не нужно ничего скачивать и устанавливать — вы попадаете на урок из личного кабинета прямо в браузере. 2. Во время урока вы одновременно общаетесь с преподавателем по видео и выполняете интерактивные задания. 3. Правильные и неправильные ответы отображаются сразу, а на полях можно делать заметки, чтобы не забыть новое слово или правило. 4. Упражнения и видеосвязь с учителем будут доступны одновременно на одной странице.   ## Обучайтесь эффективнее с приложением   В приложении вы можете не только подключаться к урокам с преподавателем и выполнять домашку, но и практиковаться самостоятельно с большим количеством упражнений и тренажёром слов — умные алгоритмы помогут выучить лексику в 3 раза быстрее среднего.   ## Все возможности платформы   1. Доступ к обучению 2. Тренажёр слов 3. Домашние задания
#
#
# =====================
# Оценка схожести: 0.2873
# ### Бесплатный вводный урок   Мы можем познакомиться еще до обучения. Для этого достаточно оставить заявку и записаться на вводное занятие. Там можно узнать, как работает онлайн-платформа, и пройти тест на уровень языка. После этого к вам подключится методист. Он поможет определить цель, подобрать нужный курс и ответит на вопросы о школе.   ### 80% разговорной практики на занятии   Студенты Skyeng начинают говорить на английском уже с первого занятия и дальше практикуются большую часть времени. Это заслуга коммуникативной методики. Ее суть в том, чтобы разговорить ученика с первых минут занятия и помочь ему переступить языковой барьер. Так вы сможете получать реальные навыки и учиться общению, вместо того чтобы быть теоретиком.   ### Опытные преподаватели

# %% [markdown]
# ## Запрос

# %% [markdown]
# ChatGPT использует идею "ролей". Каждое сообщение в списке сообщений - это набор данных, включающий два элемента: role и content. Role может быть одной из двух вещей: "system", "user", указывая, кто в данный момент "разговаривает". Content - это сам текст сообщения.
#
# Обычно, в диалоге участвуют две главные роли:
#
# "system": Роль системы используется для задания общей обстановки разговора. Это своего рода руководство для модели, указывающее, как она должна вести себя в процессе диалога.
#
# "user": Это роль человека, который ведет диалог с моделью. Ваши вопросы модели будут представлены под этой ролью. Также сюда мы можем подавать определенные инструкции для модели (самые основные и важные).

# %%
# Подгружаем промт
system = ''' # Ты профессиональный помощник в чате компании


## 1. Общие обязанности и цели - Компания продает курсы по английскому языку. У компании есть большой документ со всеми материалами
о продуктах компании. - Твоя обязанность: Дать Клиенту краткий корректный ответ на русском языке в чате, опираясь на отрывки
из этого документа. - Твоя цель: Отвечать максимально кратко и точно по документу, не придумывать ничего от себя.


## 2. Ограничения в общении - Запрещено общаться на стороннюю тему. Если Клиент задает стороннюю тему, спрашивает не
по теме английского языка, не по материалам и продуктам Компании, ты категорически отказываешься
отвечать.


## 3. Секретность документа
- Запрещено упоминать в ответе, что ты анализировал отрывки документов и брал оттуда информацию.

'''

# Инструкция для модели о том, как использовать контекст для ответа на вопрос
instruction = '''Проанализируй предыдущий диалог чтобы написать свой ответ последовательным и логичным.
Категорически запрещено повторяться и здороваться.
Используйте следующие фрагменты контекста, чтобы ответить на вопрос в конце.
Стилистика ответа должна быть поддерживающей беседу в контексте важности и полезности изучения английского языка.
Если вы не знаете ответа, просто скажите, что не знаете, не пытайтесь придумывать ответ.
Тебе запрещено продавать, предлагать курсы. Запрещено спрашивать клиента что его еще интересует.'''

# %% [markdown]
# Функция для получения ответа на вопрос на основе заданной темы и поискового индекса

# %%
def answer_index(system, instruction, topic, search_index, temp=1, verbose=0, k=3):
    """
    Параметры:
    system (str): Промт.
    instruction (str): Инструкция для пользователя.
    topic (str): Тема или вопрос, на который нужно ответить.
    search_index (object): Векторная база.
    temp (float): Температура для генерации ответов модели (по умолчанию 1).
    verbose (int): Флаг для включения/выключения подробного вывода (по умолчанию 0).
    k (int): Количество похожих документов для поиска (по умолчанию 3).
    """

    # Поиск документов, похожих на заданную тему/вопрос
    docs = search_index.similarity_search(topic, k=k)

    # Если включен подробный вывод, напечатать разделитель
    if verbose: print('\n ========\n')

    # Создание содержимого сообщения, объединяя текст найденных документов
    message_content = re.sub(r'\r\n', ' ', '\n '.join([f'\n--------------------\n' + doc.page_content + '\n' for i, doc in enumerate(docs)]))

    # Если включен подробный вывод, напечатать содержимое сообщения
    if verbose: print('Чанки :\n ======================================== \n', message_content)

    # Формирование сообщений для модели
    messages = [
        {"role": "system", "content": system},
        {"role": "user", "content": f"{instruction}.\n{message_content}.\n\nВопрос:\n{topic}\n\nОтвет:"}
    ]

    start_time = time.time()  # Начало отсчета времени

    # Создание запроса к модели OpenAI
    completion = openai.ChatCompletion.create(
        model="gpt-4o",
        messages=messages,  # Сообщения для модели
        temperature=temp
    )

    end_time = time.time()  # Конец отсчета времени
    elapsed_time2 = end_time - start_time  # Подсчет затраченного времени

    # Если включен подробный вывод, напечатать разделитель
    if verbose: print('\n =========================================== ')

    # Получение ответа от модели
    answer = completion.choices[0].message.content
    print()
    print()
    print("Полный ответ от GPT:")
    print(completion)
    print()
    print("Ответ:")
    print(answer)
    print()
    print(f"Количество использованных токенов на запрос: {completion['usage']['prompt_tokens']}")
    print(f"Количество использованных токенов на ответ: {completion['usage']['completion_tokens']}")
    print(f"Общее количество использованных токенов (вопрос-ответ): {completion['usage']['total_tokens']}")
    print()
    print('ЦЕНА запроса:', (5 * completion['usage']['prompt_tokens'] / 1000000) + (15 * completion['usage']['completion_tokens']/ 1000000), ' $')  # Вычисляем стоимость запроса
    print(f"Время ответа: {elapsed_time2:.2f} секунд")

# %% [markdown]
# Параметры для запроса

# %%
# Задаем импровизацию ответа, 0 - ответ только на основании текста наших документов
temperature = 0

# Задаем количество чанков для формирования ответа
relevant_chanks = 3

# Флаг для включения/выключения вывода релевантных чанков
verbose = 1

# %% [markdown]
# Запрос

# %%
question = "Какова продолжительность урока английского в Skyeng?"
result_df = answer_index(system, instruction, question, db, temperature, relevant_chanks)
# Out:
#  ========
#
# Чанки :
#  ========================================
#
# --------------------
# Кстати, если вы хотите отдохнуть от занятий или временно не можете приходить на уроки, в личном кабинете можно оформить отпуск. Он на время заморозит ваш прогресс. После вы сможете вернуться к занятиям, когда будете готовы. Мы подождем, и уроки не сгорят.   ## Сколько длится один урок? Одно занятие в Skyeng длится 50 минут.   ## Кто будет вести курс?   Вы будете заниматься на курсе английского языка с одним из наших учителей — опытных педагогов. Выбрать учителя можно самому — почитайте о них больше на странице «Преподаватели» и начните учиться с тем, кто вам ближе.   Есть и второй вариант. Расскажите нам о том, что вы цените в учителе, и мы сами найдем подходящего по вашим критериям. А если что-то пойдет не так, его можно будет заменить. Это легко сделать в личном кабинете.   ## Что еще входит в цену курса, кроме самого курса?
#
#
# --------------------
# Кстати, если вы хотите отдохнуть от занятий или временно не можете приходить на уроки, в личном кабинете можно оформить отпуск. Он на время заморозит ваш прогресс. После вы сможете вернуться к занятиям, когда будете готовы. Мы подождем, и уроки не сгорят.   ## Сколько длится один урок?   Одно занятие в Skyeng длится 50 минут.   ## Кто будет вести курс?   Вы будете заниматься на курсе английского языка с одним из наших учителей — опытных педагогов. Выбрать учителя можно самому — почитайте о них больше на странице «Преподаватели» и начните учиться с тем, кто вам ближе.   Есть и второй вариант. Расскажите нам о том, что вы цените в учителе, и мы сами найдем подходящего по вашим критериям. А если что-то пойдет не так, его можно будет заменить. Это легко сделать в личном кабинете.   ## Что еще входит в цену курса, кроме самого курса?
#
#
# --------------------
# Преподаватели Skyeng — это опытные педагоги, которые знают, как разговорить студента. Только 5 из 100 кандидатов проходят отбор, поэтому мы спокойны за качество их уроков. Чтобы и дальше держать эту планку высокой, наши педагоги обучаются каждый год. А еще с ними можно поговорить на любую интересную вам тему на английском.   ### Все функции — в мобильном приложении   В приложении Skyeng мы собрали все, что поможет вам управлять обучением. Здесь вы можете видеть статистику по пройденным темам и следить за своим прогрессом. 24/7 в приложении доступны тренировки и словари. В нем же можно поменять расписание, перенести урок или взять отпуск на месяц. А если понадобится помощь, можно связаться с техподдержкой или учителем английского.   # Курсы английского языка для продолжающих
#
#
#  ===========================================
#
#
# Полный ответ от GPT:
# {
#   "id": "chatcmpl-A36IpHxhUY9CbEKBhFlHC8vijXp19",
#   "object": "chat.completion",
#   "created": 1725302575,
#   "model": "gpt-4o-2024-05-13",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "\u041e\u0434\u043d\u043e \u0437\u0430\u043d\u044f\u0442\u0438\u0435 \u0432 Skyeng \u0434\u043b\u0438\u0442\u0441\u044f 50 \u043c\u0438\u043d\u0443\u0442.",
#         "refusal": null
#       },
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 1016,
#     "completion_tokens": 13,
#     "total_tokens": 1029
#   },
#   "system_fingerprint": "fp_157b3831f5"
# }
#
# Ответ:
# Одно занятие в Skyeng длится 50 минут.
#
# Количество использованных токенов на запрос: 1016
# Количество использованных токенов на ответ: 13
# Общее количество использованных токенов (вопрос-ответ): 1029
#
# ЦЕНА запроса: 0.005275  $
# Время ответа: 0.52 секунд

# %% [markdown]
# Запрос с добавлением истории диалога

# %%
def answer_kons_d(system, instruction, topic, search_index, summary_history, temp=1, verbose=0, k=3):
    """
    Параметры:
    system (str): Промт.
    instruction (str): Инструкция для пользователя.
    topic (str): Тема или вопрос, на который нужно ответить.
    search_index (object): Векторная база.
    summary_history (str): История предыдущих сообщений диалога.
    temp (float): Температура для генерации ответов модели (по умолчанию 1).
    verbose (int): Флаг для включения/выключения подробного вывода (по умолчанию 0).
    k (int): Количество похожих документов для поиска (по умолчанию 8).
    """

    # Поиск документов, похожих на заданную тему/вопрос
    docs = search_index.similarity_search(topic, k=k)

    # Создание содержимого сообщения, объединяя текст найденных документов
    message_content = re.sub(r'\r\n', ' ', '\n '.join([f'\n--------------------\n' + doc.page_content + '\n' for i, doc in enumerate(docs)]))

    # Если включен подробный вывод, напечатать содержимое сообщения
    if verbose: print('Чанки :\n ======================================== \n', message_content)

    # Формирование сообщений для модели
    messages = [
        {"role": "system", "content": system},
        {"role": "user", "content": f"{instruction}.\n{message_content}.\n\nВопрос:\n{topic}\n\nХронология предыдущих сообщений диалога: {summary_history}\n\nОтвет:"}
    ]

    # Создание запроса к модели OpenAI
    completion = openai.ChatCompletion.create(
        model="gpt-4o",
        messages=messages,  # Сообщения для модели
        temperature=temp
    )

    # Получение ответа от модели
    answer = completion.choices[0].message.content

    print('\n==================')
    print("Менеджер:")
    # Форматирование ответа для удобства чтения
    formatted_answer = textwrap.fill(answer, width=120)
    if verbose: print(formatted_answer)

    return answer

# %% [markdown]
# Параметры для запроса

# %%
# Задаем импровизацию ответа, 0 - ответ только на основании текста наших документов
temperature = 0

# Задаем количество чанков для формирования ответа
relevant_chanks = 3

# Флаг для включения/выключения вывода релевантных чанков
verbose = 0

# %% [markdown]
# Запрос без истории

# %%
# Вопрос
topic = "А если два?"

# История диалога
history = [""]

# Вызов функции answer_kons_d с корректным именем переменной для хранения результата
answer_response = answer_kons_d(system, instruction, topic, db, history, temperature, verbose, relevant_chanks)
print(answer_response)
# Out:
# ==================
# Менеджер:
# Одно занятие в Skyeng длится 50 минут.

# %% [markdown]
# Запрос с историей

# %%
# Вопрос
topic = "А если два?"

# История диалога
history = ["Сколько раз в неделю необходимо заниматься?", "Для достижения наилучших результатов мы рекомендуем заниматься 3 раза в неделю."]

# Вызов функции answer_kons_d с корректным именем переменной для хранения результата
answer_response = answer_kons_d(system, instruction, topic, db, history, temperature, verbose, relevant_chanks)
print(answer_response)
# Out:
# ==================
# Менеджер:
# Если два раза в неделю, прогресс будет медленнее, но вы все равно сможете достичь своих целей. Главное — регулярность и мотивация.

# %% [markdown]
# ## Диалог

# %%
# Подгружаем промты
system = '''
Ты профессиональный помощник в чате компании.

## 1. Общие обязанности и цели
- Компания продает курсы по английскому языку. У компании есть большой документ со всеми материалами о продуктах компании.
- Твоя обязанность: Дать Клиенту краткий корректный ответ на русском языке в чате, опираясь на отрывки из этого документа.
- Твоя цель: Отвечать максимально кратко и точно по документу, не придумывать ничего от себя.

## 2. Ограничения в общении
- Запрещено общаться на стороннюю тему. Если Клиент задает вопрос не по теме английского языка, не по материалам и продуктам Компании, ты категорически отказываешься отвечать.

## 3. Секретность документа
- Запрещено упоминать в ответе, что ты анализировал отрывки документов и брал оттуда информацию.
'''

instruction = '''
Проанализируй предыдущий диалог чтобы написать свой ответ последовательным и логичным.
Категорически запрещено повторяться и здороваться.
Используй следующие фрагменты контекста, чтобы ответить на вопрос в конце.
Стилистика ответа должна быть поддерживающей беседу в контексте важности и полезности изучения английского языка.
Если вы не знаете ответа, просто скажите, что не знаете, не пытайтесь придумывать ответ.
Тебе запрещено продавать, предлагать курсы. Запрещено спрашивать клиента что его еще интересует.
'''

# Функция для генерации ответа на вопрос пользователя на основе всей истории диалога
def answer_kons_d(system, instruction, summary_history, search_index):
    # Поиск документов, похожих на заданную тему/вопрос на основе всей истории диалога
    docs = search_index.similarity_search(summary_history, k=3)

    # Создание содержимого сообщения, объединяя текст найденных документов
    message_content = re.sub(r'\r\n', ' ', '\n '.join([f'\n--------------------\n' + doc.page_content + '\n' for doc in docs]))

    # Формирование сообщений для модели
    messages = [
        {"role": "system", "content": system},
        {"role": "user", "content": f"{instruction}.\n{message_content}.\n\nИстория диалога:\n{summary_history}\n\nОтвет:"}
    ]

    # Создание запроса к модели OpenAI
    completion = openai.ChatCompletion.create(
        model="gpt-4o",
        messages=messages,
        temperature=0
    )

    # Получение ответа от модели
    answer = completion.choices[0].message.content
    return answer

# Функция для генерации следующего вопроса на основе всей истории диалога
def generate_follow_up_question(summary_history, search_index):
    follow_up_system = '''
    Ты профессиональный помощник в чате компании.
    '''
    follow_up_instruction = '''
    Проанализируй предыдущую историю диалога, чтобы задать один дополнительный вопрос на основании всей истории.
    Больше ничего не пиши. Укажи этот вопрос явно и лаконично.
    '''

    # Генерация следующего вопроса на основе истории диалога
    follow_up_question = answer_kons_d(
        system=follow_up_system,
        instruction=follow_up_instruction,
        summary_history=summary_history,
        search_index=search_index
    )

    return follow_up_question

# Основная функция для запуска бота и обработки диалога с пользователем
def run_bot():
    history_chat = []
    search_index = db  # Подгружаем индекс FAISS

    # Стандартный первый вопрос
    initial_question = "Здравствуйте! Какой у вас вопрос по курсам английского языка?"
    print(f"БОТ: {initial_question}")
    history_chat.append(f"БОТ: {initial_question}")

    while True:
        client_question = input("Пользователь: ").strip()
        if client_question.lower() in ['stop', 'стоп']:
            print("БОТ: Завершаю диалог. Всего доброго!")
            break

        # Сохраняем вопрос клиента в истории
        history_chat.append(f"Пользователь: {client_question}")

        # Генерация ответа на вопрос
        answer = answer_kons_d(
            system=system,
            instruction=instruction,
            summary_history='\n'.join(history_chat),
            search_index=search_index
        )

        # Вывод и сохранение ответа бота
        print(f"БОТ: {answer}")
        history_chat.append(f"БОТ: {answer}")

        # Генерация нового вопроса на основе всей истории диалога
        follow_up_question = generate_follow_up_question(
            summary_history='\n'.join(history_chat),
            search_index=search_index
        )

        # Вывод и сохранение нового вопроса
        print(f"БОТ: {follow_up_question}")
        history_chat.append(f"БОТ: {follow_up_question}")

# Запуск бота
run_bot()
# Out:
# БОТ: Здравствуйте! Какой у вас вопрос по курсам английского языка?
# Пользователь: С чего начать изучени английского?
# БОТ: Начните изучать английский с нуля, расширяя словарный запас, разбираясь в грамматике и учась понимать живую речь на слух. Это поможет свободно общаться, читать и писать на английском. Программа обучения включает 44 онлайн-урока и 9 тематических модулей, начиная с основ, таких как представление себя и знакомство с другими людьми.
# БОТ: Когда вам будет удобно записаться на бесплатный вводный урок?
# Пользователь: Давайте на завтра
# БОТ: Отлично! Завтра мы сможем познакомить вас с нашей онлайн-платформой и помочь найти цель и подходящего учителя. Вы сможете начать понимать иностранную речь, читать, грамотно писать и бегло разговаривать.
# БОТ: Какое время завтра вам будет удобно для вводного урока?
# Пользователь: 20:00
# БОТ: Завтра в 20:00 мы проведем для вас вводный урок. Вы познакомитесь с нашей онлайн-платформой, и мы поможем вам найти цель и подходящего учителя.
# БОТ: Хотите получить бесплатный личный план по изучению английского?
# Пользователь: Конечно
# БОТ: Ваш вводный урок запланирован на завтра в 20:00. На уроке вы познакомитесь с нашей онлайн-платформой и получите помощь в определении цели и выборе подходящего учителя. Также мы подготовим для вас бесплатный личный план по изучению английского.
# БОТ: Хотите ли вы участвовать в бесплатном 15-дневном марафоне для формирования привычки учить английский?
# Пользователь: Хочу!
# БОТ: Ваш вводный урок запланирован на завтра в 20:00. На уроке вы познакомитесь с нашей онлайн-платформой, получите помощь в определении цели и выборе подходящего учителя, а также бесплатный личный план по изучению английского. Кроме того, вы сможете участвовать в бесплатном 15-дневном марафоне для формирования привычки учить английский.
# БОТ: Хотите ли вы получить доступ к 10 дням бесплатных занятий в нашем телеграм-боте?
# Пользователь: стоп
# БОТ: Завершаю диалог. Всего доброго!
